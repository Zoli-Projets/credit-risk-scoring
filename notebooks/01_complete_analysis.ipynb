# %% [markdown]
# # <p style="text-align: center; color: blue; font-size: 55px;"><strong> Projet: Modélisation Credit Risque </strong></p>

# %% [markdown]
# ###### <p style="text-align: center; color: blue; font-size: 25px;"><strong> Introduction</strong></p>

# %% [markdown]
# <p  font-size: 15px;"><strong> Dans un monde où la bancarisation s'intensifie et où les services financiers se digitalisent de plus en plus, les établissements de crédit se retrouvent face à un défi majeur : évaluer, en quelques secondes seulement, le risque associé à chaque demande de prêt. L'augmentation du volume de ces demandes, la diversité des profils des emprunteurs et les exigences réglementaires strictes en matière de gestion des risques rendent impérative l’adoption d’outils de scoring à la fois précis et transparents.
#
# Ce projet vise à concevoir un système de scoring innovant capable de prédire instantanément la probabilité de défaut d’un demandeur en fonction de ses caractéristiques socio-démographiques, de son historique de crédit, ainsi que des données liées au prêt demandé. En exploitant des jeux de données comprenant des informations sur les clients (customers.csv), les prêts (loans.csv) et l’historique des bureaux de crédit (bureau_data.csv), notre objectif est de construire un modèle de risque qui classe chaque demande dans l’une des catégories suivantes : Faible, Moyen, Bon, ou Excellent, en estimant la probabilité de défaut de manière fiable.
#
# Le travail s’organise autour de plusieurs étapes essentielles : une présentation détaillée des jeux de données, le prétraitement et le nettoyage des données, la modélisation à l’aide de techniques avancées telles que la régression logistique et les forêts aléatoires, puis l’évaluation et la comparaison des performances des modèles. L’aboutissement de cette démarche sera la proposition d’un outil d’aide à la décision performant pour l’octroi de crédits.</strong></p>

# %% [markdown]
# ## <p style="text-align: center; color: blue; font-size: 25px;"><strong> I. Importation des librairies et chargement des données</strong></p>
#
# Dans cette première étape, on importe les principales librairies nécessaires (pandas, numpy, seaborn, matplotlib) et on charge les trois fichiers de données :
# - `loans.csv` : informations détaillées sur les prêts (montants, type, dates, défaut, etc.)
# - `customers.csv` : caractéristiques des clients (âge, revenus, situation pro, etc.)
# - `bureau_data.csv` : historique crédit au bureau (nombre de comptes, delinquencies, utilisation crédit...).

# %% [markdown]
# ### I.1 **Explications des variables**
#
# ### **loans.csv** - Détails des prêts
#
# | Colonne | Signification |
# |---------|---------------|
# | `loan_id` | ID unique du prêt |
# | `cust_id` | ID unique du client |
# | `loan_purpose` | Objectif : Home, Auto, Personal, Education |
# | `loan_type` | Type : Secured (garanti), Unsecured |
# | `sanction_amount` | Montant **approuvé** (INR) |
# | `loan_amount` | Montant **emprunté** (INR) |
# | `processing_fee` | Frais de traitement |
# | `gst` | Taxe GST (18%) |
# | `net_disbursement` | **Montant net versé** |
# | `loan_tenure_months` | Durée en mois |
# | `principal_outstanding` | Capital restant dû |
# | `bank_balance_at_application` | Solde bancaire à la demande |
# | `disbursal_date` | Date déblocage prêt |
# | `installment_start_dt` | Date 1ère échéance |
# | `default` | **Cible** : 1=défaut, 0=OK |
#
# ### **customers.csv** - Profil clients
#
# | Colonne | Signification |
# |---------|---------------|
# | `cust_id` | ID unique du client |
# | `age` | Âge |
# | `gender` | Genre|
# | `experience` | Années expérience pro |
# | `marital_status` | Etat civil, Marié/Célibataire |
# | `employment_status` | Statut professionnel du client|
# | `income` | Revenu annuel|
# | `number_of_dependants` | Nombre de personnes à charge du client|
# | `residence_type` | Type de résidence |
# | `years_at_current_address` | nombre d'années passées à l'adresse actuelle. |
# | `city` | Ville |
# | `state` | État ou région de résidence du client |
# | `zipcode` |Code postal de l'adresse du client|
#
# ### **bureau_data.csv** - Historique crédit
# | Colonne | Signification |
# |---------|---------------|
# | `cust_id` | ID unique du client |
# | `number_of_open_accounts` |Nombre de comptes de crédit ouverts par le client |
# | `number_of_closed_accounts` | Nombre de comptes de crédit fermés par le client.|
# | `total_loan_months` | Nombre total de mois pendant lesquels le client a eu des prêts |
# | `delinquent_months` | Nombre de mois durant lesquels le client a eu des retards de paiement |
# | `total_dpd` | Nombre total de jours de retard accumulés sur les paiements |
# | `enquiry_count` | Nombre de demandes de crédit effectuées par le client |
# | `credit_utilization_ratio` | Ratio de l’utilisation du crédit |

# %% [markdown]
# ### I.2 **Chargement des données**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

pd.set_option("display.max_columns", 100)

from src.data.load_data import load_all_data

loans, customers, bureau = load_all_data()

print(loans.shape)

print(customers.shape)

print(bureau.shape)

loans.head()
# Out:
# loans : (50000, 15)
# customers : (50000, 12)
# bureau : (50000, 8)
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
# 3  L00004  C00004     Personal  Unsecured          2345000      1747000
# 4  L00005  C00005         Auto    Secured          4647000      4520000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0         49340.0  444060           1973600                  33
# 1         77660.0  698940           3106400                  30
# 2         43400.0  390600           1736000                  21
# 3         34940.0  314460           1397600                   6
# 4         90400.0  813600           3616000                  28
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
# 3                1257839                      1031094     2019-07-24
# 4                1772334                      1032458     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False
# 3           2019-08-09    False
# 4           2019-08-02    False

# %%
customers.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001
# 3    Karnataka   560001
# 4  Maharashtra   411001

# %%
customers.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode'],
#       dtype='object')

# %%
bureau.head()
# Out:
#   cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 0  C00001                        1                          1
# 1  C00002                        3                          1
# 2  C00003                        2                          1
# 3  C00004                        3                          0
# 4  C00005                        4                          2
#
#    total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                 42                  0          0              3
# 1                 96                 12         60              5
# 2                 82                 24        147              6
# 3                115                 15         87              5
# 4                120                  0          0              5
#
#    credit_utilization_ratio
# 0                         7
# 1                         4
# 2                        58
# 3                        26
# 4                        10

# %%
bureau.columns
# Out:
# Index(['cust_id', 'number_of_open_accounts', 'number_of_closed_accounts',
#        'total_loan_months', 'delinquent_months', 'total_dpd', 'enquiry_count',
#        'credit_utilization_ratio'],
#       dtype='object')

# %%
loans.head()
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
# 3  L00004  C00004     Personal  Unsecured          2345000      1747000
# 4  L00005  C00005         Auto    Secured          4647000      4520000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0         49340.0  444060           1973600                  33
# 1         77660.0  698940           3106400                  30
# 2         43400.0  390600           1736000                  21
# 3         34940.0  314460           1397600                   6
# 4         90400.0  813600           3616000                  28
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
# 3                1257839                      1031094     2019-07-24
# 4                1772334                      1032458     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False
# 3           2019-08-09    False
# 4           2019-08-02    False

# %%
loans.columns
# Out:
# Index(['loan_id', 'cust_id', 'loan_purpose', 'loan_type', 'sanction_amount',
#        'loan_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'disbursal_date', 'installment_start_dt',
#        'default'],
#       dtype='object')

# %% [markdown]
# ###### <p style="text-align: center; color: blue; font-size: 25px;"><strong>II. Prétraitement et nettoyage des données</strong></p>

# %% [markdown]
# ### II.1 **CONVERSION DE LA MONNAIE EN EURO (€ / EUR)**

# %%
from src.data.currency import convert_currency

customers, loans = convert_currency(

    customers,

    loans
)

# %% [markdown]
# ### II.2 **Fusion des tables `customers`, `loans` et `bureau`**

# %%
from src.data.merge_data import merge_data

df = merge_data(

    customers,

    loans,

    bureau
)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  28446.0
# 1  C00002   38      M        Married          Salaried  13266.0
# 2  C00003   46      F        Married     Self-Employed  31658.0
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#          state  zipcode loan_id loan_purpose  loan_type  sanction_amount  \
# 0        Delhi   110001  L00001         Auto    Secured          33044.0
# 1   Tamil Nadu   600001  L00002         Home    Secured          45771.0
# 2  West Bengal   700001  L00003     Personal  Unsecured          26411.0
#
#    loan_amount  processing_fee      gst  net_disbursement  loan_tenure_months  \
# 0      27137.0          542.74  4884.66           21709.6                  33
# 1      42713.0          854.26  7688.34           34170.4                  30
# 2      23870.0          477.40  4296.60           19096.0                  21
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0              17934.488                     9607.246     2019-07-24
# 1               7802.399                     5105.100     2019-07-24
# 2              17186.389                    16236.462     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False

# %%
df.info
# Out:
# <bound method DataFrame.info of       cust_id  age gender marital_status employment_status   income  \
# 0      C00001   44      M        Married     Self-Employed  28446.0
# 1      C00002   38      M        Married          Salaried  13266.0
# 2      C00003   46      F        Married     Self-Employed  31658.0
# 3      C00004   55      F         Single     Self-Employed  39017.0
# 4      C00005   37      M        Married          Salaried  37752.0
# ...       ...  ...    ...            ...               ...      ...
# 49995  C49996   40      F         Single          Salaried   8525.0
# 49996  C49997   39      M         Single          Salaried  34287.0
# 49997  C49998   45      F         Single     Self-Employed  14619.0
# 49998  C49999   42      F         Single     Self-Employed   5863.0
# 49999  C50000   55      M        Married     Self-Employed  34584.0
#
#        number_of_dependants residence_type  years_at_current_address  \
# 0                         3          Owned                        27
# 1                         3          Owned                         4
# 2                         3          Owned                        24
# 3                         1          Owned                        15
# 4                         3          Owned                        28
# ...                     ...            ...                       ...
# 49995                     2          Owned                        11
# 49996                     0          Owned                         9
# 49997                     0         Rented                        27
# 49998                     2       Mortgage                        20
# 49999                     3          Owned                        19
#
#             city        state  zipcode loan_id loan_purpose  loan_type  \
# 0          Delhi        Delhi   110001  L00001         Auto    Secured
# 1        Chennai   Tamil Nadu   600001  L00002         Home    Secured
# 2        Kolkata  West Bengal   700001  L00003     Personal  Unsecured
# 3      Bangalore    Karnataka   560001  L00004     Personal  Unsecured
# 4           Pune  Maharashtra   411001  L00005         Auto    Secured
# ...          ...          ...      ...     ...          ...        ...
# 49995    Chennai   Tamil Nadu   600001  L49996     Personal  Unsecured
# 49996    Kolkata  West Bengal   700001  L49997         Auto    Secured
# 49997  Bangalore    Karnataka   560001  L49998         Home    Secured
# 49998  Hyderabad    Telangana   500001  L49999         Home    Secured
# 49999     Mumbai  Maharashtra   400001  L50000         Home    Secured
#
#        sanction_amount  loan_amount  processing_fee       gst  \
# 0              33044.0      27137.0          542.74   4884.66
# 1              45771.0      42713.0          854.26   7688.34
# 2              26411.0      23870.0          477.40   4296.60
# 3              25795.0      19217.0          384.34   3459.06
# 4              51117.0      49720.0          994.40   8949.60
# ...                ...          ...             ...       ...
# 49995           6710.0       5885.0          117.70   1059.30
# 49996          46321.0      35673.0          713.46   6421.14
# 49997          45067.0      41140.0          822.80   7405.20
# 49998          20581.0      17930.0          358.60   3227.40
# 49999          91058.0      68926.0         1378.52  12406.68
#
#        net_disbursement  loan_tenure_months  principal_outstanding  \
# 0               21709.6                  33              17934.488
# 1               34170.4                  30               7802.399
# 2               19096.0                  21              17186.389
# 3               15373.6                   6              13836.229
# 4               39776.0                  28              19495.674
# ...                 ...                 ...                    ...
# 49995            4708.0                  22               4237.189
# 49996           28538.4                  15              18221.324
# 49997           32912.0                  37              10039.601
# 49998           14344.0                  37               3300.385
# 49999           55140.8                  38              17816.579
#
#        bank_balance_at_application disbursal_date installment_start_dt  \
# 0                         9607.246     2019-07-24           2019-08-10
# 1                         5105.100     2019-07-24           2019-08-15
# 2                        16236.462     2019-07-24           2019-08-21
# 3                        11342.034     2019-07-24           2019-08-09
# 4                        11357.038     2019-07-24           2019-08-02
# ...                            ...            ...                  ...
# 49995                     1963.170     2024-07-22           2024-08-15
# 49996                    11448.085     2024-07-22           2024-07-29
# 49997                     3910.071     2024-07-22           2024-07-25
# 49998                     1973.983     2024-07-22           2024-07-29
# 49999                    15002.614     2024-07-22           2024-08-08
#
#        default
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
#
# [50000 rows x 26 columns]>

# %%
df = pd.merge(df, bureau, on='cust_id')
df.head(10)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  28446.0
# 1  C00002   38      M        Married          Salaried  13266.0
# 2  C00003   46      F        Married     Self-Employed  31658.0
# 3  C00004   55      F         Single     Self-Employed  39017.0
# 4  C00005   37      M        Married          Salaried  37752.0
# 5  C00006   37      M        Married     Self-Employed  12705.0
# 6  C00007   55      M        Married     Self-Employed  35805.0
# 7  C00008   47      F         Single     Self-Employed   3905.0
# 8  C00009   35      M         Single          Salaried  15884.0
# 9  C00010   45      M         Single          Salaried  24530.0
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
# 5                     5          Owned                         5       Pune
# 6                     3       Mortgage                        21  Bangalore
# 7                     0       Mortgage                         3       Pune
# 8                     1          Owned                         5  Bangalore
# 9                     0          Owned                         1     Jaipur
#
#          state  zipcode loan_id loan_purpose  loan_type  sanction_amount  \
# 0        Delhi   110001  L00001         Auto    Secured          33044.0
# 1   Tamil Nadu   600001  L00002         Home    Secured          45771.0
# 2  West Bengal   700001  L00003     Personal  Unsecured          26411.0
# 3    Karnataka   560001  L00004     Personal  Unsecured          25795.0
# 4  Maharashtra   411001  L00005         Auto    Secured          51117.0
# 5  Maharashtra   411001  L00006     Personal  Unsecured          10549.0
# 6    Karnataka   560001  L00007     Personal  Unsecured          24772.0
# 7  Maharashtra   411001  L00008    Education    Secured           6017.0
# 8    Karnataka   560001  L00009         Auto    Secured          22385.0
# 9    Rajasthan   302001  L00010     Personal  Unsecured          18766.0
#
#    loan_amount  processing_fee      gst  net_disbursement  loan_tenure_months  \
# 0      27137.0          542.74  4884.66           21709.6                  33
# 1      42713.0          854.26  7688.34           34170.4                  30
# 2      23870.0          477.40  4296.60           19096.0                  21
# 3      19217.0          384.34  3459.06           15373.6                   6
# 4      49720.0          994.40  8949.60           39776.0                  28
# 5       8382.0          167.64  1508.76            6705.6                  14
# 6      24365.0          487.30  4385.70           19492.0                  11
# 7       4576.0           91.52   823.68            3660.8                  36
# 8      20779.0          415.58  3740.22           16623.2                  30
# 9      18238.0          364.76  3282.84           14590.4                   6
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0              17934.488                     9607.246     2019-07-24
# 1               7802.399                     5105.100     2019-07-24
# 2              17186.389                    16236.462     2019-07-24
# 3              13836.229                    11342.034     2019-07-24
# 4              19495.674                    11357.038     2019-07-24
# 5               6005.615                     4297.744     2019-07-24
# 6              17542.789                     8455.777     2019-07-24
# 7               2726.702                      881.892     2019-07-24
# 8               9378.666                     8347.592     2019-07-24
# 9              11697.213                     9587.490     2019-07-25
#
#   installment_start_dt  default  number_of_open_accounts  \
# 0           2019-08-10    False                        1
# 1           2019-08-15    False                        3
# 2           2019-08-21    False                        2
# 3           2019-08-09    False                        3
# 4           2019-08-02    False                        4
# 5           2019-08-19    False                        1
# 6           2019-08-22    False                        2
# 7           2019-08-02    False                        2
# 8           2019-07-25    False                        1
# 9           2019-08-05    False                        1
#
#    number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                          1                 42                  0          0
# 1                          1                 96                 12         60
# 2                          1                 82                 24        147
# 3                          0                115                 15         87
# 4                          2                120                  0          0
# 5                          0                 42                 14         74
# 6                          2                 79                  2         16
# 7                          0                 52                  0          0
# 8                          0                  5                  0          0
# 9                          0                 40                 10         45
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
# 3              5                        26
# 4              5                        10
# 5              2                        37
# 6              4                        12
# 7              3                         2
# 8              2                        15
# 9              2                        49

# %%
df.info
# Out:
# <bound method DataFrame.info of       cust_id  age gender marital_status employment_status   income  \
# 0      C00001   44      M        Married     Self-Employed  28446.0
# 1      C00002   38      M        Married          Salaried  13266.0
# 2      C00003   46      F        Married     Self-Employed  31658.0
# 3      C00004   55      F         Single     Self-Employed  39017.0
# 4      C00005   37      M        Married          Salaried  37752.0
# ...       ...  ...    ...            ...               ...      ...
# 49995  C49996   40      F         Single          Salaried   8525.0
# 49996  C49997   39      M         Single          Salaried  34287.0
# 49997  C49998   45      F         Single     Self-Employed  14619.0
# 49998  C49999   42      F         Single     Self-Employed   5863.0
# 49999  C50000   55      M        Married     Self-Employed  34584.0
#
#        number_of_dependants residence_type  years_at_current_address  \
# 0                         3          Owned                        27
# 1                         3          Owned                         4
# 2                         3          Owned                        24
# 3                         1          Owned                        15
# 4                         3          Owned                        28
# ...                     ...            ...                       ...
# 49995                     2          Owned                        11
# 49996                     0          Owned                         9
# 49997                     0         Rented                        27
# 49998                     2       Mortgage                        20
# 49999                     3          Owned                        19
#
#             city        state  zipcode loan_id loan_purpose  loan_type  \
# 0          Delhi        Delhi   110001  L00001         Auto    Secured
# 1        Chennai   Tamil Nadu   600001  L00002         Home    Secured
# 2        Kolkata  West Bengal   700001  L00003     Personal  Unsecured
# 3      Bangalore    Karnataka   560001  L00004     Personal  Unsecured
# 4           Pune  Maharashtra   411001  L00005         Auto    Secured
# ...          ...          ...      ...     ...          ...        ...
# 49995    Chennai   Tamil Nadu   600001  L49996     Personal  Unsecured
# 49996    Kolkata  West Bengal   700001  L49997         Auto    Secured
# 49997  Bangalore    Karnataka   560001  L49998         Home    Secured
# 49998  Hyderabad    Telangana   500001  L49999         Home    Secured
# 49999     Mumbai  Maharashtra   400001  L50000         Home    Secured
#
#        sanction_amount  loan_amount  processing_fee       gst  \
# 0              33044.0      27137.0          542.74   4884.66
# 1              45771.0      42713.0          854.26   7688.34
# 2              26411.0      23870.0          477.40   4296.60
# 3              25795.0      19217.0          384.34   3459.06
# 4              51117.0      49720.0          994.40   8949.60
# ...                ...          ...             ...       ...
# 49995           6710.0       5885.0          117.70   1059.30
# 49996          46321.0      35673.0          713.46   6421.14
# 49997          45067.0      41140.0          822.80   7405.20
# 49998          20581.0      17930.0          358.60   3227.40
# 49999          91058.0      68926.0         1378.52  12406.68
#
#        net_disbursement  loan_tenure_months  principal_outstanding  \
# 0               21709.6                  33              17934.488
# 1               34170.4                  30               7802.399
# 2               19096.0                  21              17186.389
# 3               15373.6                   6              13836.229
# 4               39776.0                  28              19495.674
# ...                 ...                 ...                    ...
# 49995            4708.0                  22               4237.189
# 49996           28538.4                  15              18221.324
# 49997           32912.0                  37              10039.601
# 49998           14344.0                  37               3300.385
# 49999           55140.8                  38              17816.579
#
#        bank_balance_at_application disbursal_date installment_start_dt  \
# 0                         9607.246     2019-07-24           2019-08-10
# 1                         5105.100     2019-07-24           2019-08-15
# 2                        16236.462     2019-07-24           2019-08-21
# 3                        11342.034     2019-07-24           2019-08-09
# 4                        11357.038     2019-07-24           2019-08-02
# ...                            ...            ...                  ...
# 49995                     1963.170     2024-07-22           2024-08-15
# 49996                    11448.085     2024-07-22           2024-07-29
# 49997                     3910.071     2024-07-22           2024-07-25
# 49998                     1973.983     2024-07-22           2024-07-29
# 49999                    15002.614     2024-07-22           2024-08-08
#
#        default  number_of_open_accounts  number_of_closed_accounts  \
# 0        False                        1                          1
# 1        False                        3                          1
# 2        False                        2                          1
# 3        False                        3                          0
# 4        False                        4                          2
# ...        ...                      ...                        ...
# 49995    False                        4                          2
# 49996    False                        4                          0
# 49997    False                        4                          1
# 49998    False                        1                          2
# 49999    False                        2                          0
#
#        total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                     42                  0          0              3
# 1                     96                 12         60              5
# 2                     82                 24        147              6
# 3                    115                 15         87              5
# 4                    120                  0          0              5
# ...                  ...                ...        ...            ...
# 49995                165                  1          6              8
# 49996                161                  0          0              4
# 49997                 42                  0          0              7
# 49998                 42                  9         47              4
# 49999                 65                 13         66              7
#
#        credit_utilization_ratio
# 0                             7
# 1                             4
# 2                            58
# 3                            26
# 4                            10
# ...                         ...
# 49995                        24
# 49996                        91
# 49997                        38
# 49998                        17
# 49999                        28
#
# [50000 rows x 33 columns]>

# %% [markdown]
# ### II.3 **Conversion de la variable 'default' en numerique**

# %%
df['default'] = df['default'].astype(int)
df.default.value_counts()
# Out:
# default
# 0    45703
# 1     4297
# Name: count, dtype: int64

# %% [markdown]
# *On observe qu'il y'a  **45 703** clients n’ont pas eu de défaut de remboursement (*default = 0*), contre **4 297** clients en défaut (*default = 1*). Cela représente environ **91,4 %** de non-défaut et **8,6 %** de défaut.*

# %% [markdown]
# ### II.3.1 **Colonnes à exclure du modèle**
# ### Ces colonnes sont des identifiants ou des dates à dropper avant modélisation ###

# %%
cols_to_drop = ['cust_id', 'loan_id', 'disbursal_date', 'installment_start_dt', 'zipcode', 'city', 'state']

# %%
df = df.drop(cols_to_drop, axis='columns')

# %% [markdown]
# ### II.3.2 **One-Hot Encoding sur nos variables catégorielles**

# %%
df['loan_purpose'] = df['loan_purpose'].str.strip().replace('Personaal', 'Personal')

# %%
df = pd.get_dummies(df, columns=['gender', 'marital_status', 'employment_status',
                                  'residence_type', 'loan_purpose', 'loan_type'],
                    drop_first=True, dtype=int)

# %% [markdown]
# ### II.4 **Séparation des variables explicatives et de la cible + division Train/Test**

# %% [markdown]
# **On fait un train/test split pour vérifier que le modèle généralise bien et ne se contente pas de « mémoriser » les données d’apprentissage,**
# **afin d'éviter le surapprentissage**

# %%
X = df.drop("default", axis="columns")
y = df['default']

X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.25,random_state=42)

df_train = pd.concat([X_train, y_train], axis="columns")
df_test = pd.concat([X_test, y_test], axis="columns")
df_train.head(3)
# Out:
#        age    income  number_of_dependants  years_at_current_address  \
# 12746   59  124597.0                     3                        30
# 32495   44    7865.0                     0                        27
# 43675   38   35145.0                     0                        26
#
#        sanction_amount  loan_amount  processing_fee       gst  \
# 12746         364331.0     257862.0         5157.24  46415.16
# 32495          12925.0      12639.0          252.78   2275.02
# 43675         125499.0     124256.0         2485.12  22366.08
#
#        net_disbursement  loan_tenure_months  principal_outstanding  \
# 12746          206289.6                  28              55000.000
# 32495           10111.2                  50               5139.519
# 43675           99404.8                  32              18224.503
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                    53025.786                        4
# 32495                     2383.667                        3
# 43675                    15222.262                        1
#
#        number_of_closed_accounts  total_loan_months  delinquent_months  \
# 12746                          2                152                 20
# 32495                          1                160                 10
# 43675                          1                 54                 12
#
#        total_dpd  enquiry_count  credit_utilization_ratio  gender_M  \
# 12746        118              4                        36         1
# 32495         62              5                         5         0
# 43675         67              4                         0         1
#
#        marital_status_Single  employment_status_Self-Employed  \
# 12746                      0                                1
# 32495                      1                                0
# 43675                      1                                0
#
#        residence_type_Owned  residence_type_Rented  loan_purpose_Education  \
# 12746                     1                      0                       0
# 32495                     1                      0                       1
# 43675                     0                      0                       0
#
#        loan_purpose_Home  loan_purpose_Personal  loan_type_Unsecured  default
# 12746                  1                      0                    0        0
# 32495                  0                      0                    0        0
# 43675                  1                      0                    0        0

# %% [markdown]
# ### II.5 **Vérification des valeurs manquantes et des doublons**

# %%
df_train.shape
# Out:
# (37500, 29)

# %%
df_train.isna().sum()
# Out:
# age                                0
# income                             0
# number_of_dependants               0
# years_at_current_address           0
# sanction_amount                    0
# loan_amount                        0
# processing_fee                     0
# gst                                0
# net_disbursement                   0
# loan_tenure_months                 0
# principal_outstanding              0
# bank_balance_at_application        0
# number_of_open_accounts            0
# number_of_closed_accounts          0
# total_loan_months                  0
# delinquent_months                  0
# total_dpd                          0
# enquiry_count                      0
# credit_utilization_ratio           0
# gender_M                           0
# marital_status_Single              0
# employment_status_Self-Employed    0
# residence_type_Owned               0
# residence_type_Rented              0
# loan_purpose_Education             0
# loan_purpose_Home                  0
# loan_purpose_Personal              0
# loan_type_Unsecured                0
# default                            0
# dtype: int64

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.describe()
# Out:
#                 age         income  number_of_dependants  \
# count  37500.000000   37500.000000          37500.000000
# mean      39.540587   28966.587760              1.944533
# std        9.858344   28861.585685              1.535943
# min       18.000000       0.000000              0.000000
# 25%       33.000000    8822.000000              0.000000
# 50%       39.000000   20735.000000              2.000000
# 75%       46.000000   36588.750000              3.000000
# max       70.000000  131989.000000              5.000000
#
#        years_at_current_address  sanction_amount    loan_amount  \
# count              37500.000000     37500.000000   37500.000000
# mean                  15.997787     51696.607307   43956.745067
# std                    8.921041     68836.162803   59090.485222
# min                    1.000000         0.000000       0.000000
# 25%                    8.000000     12562.000000   10571.000000
# 50%                   16.000000     29084.000000   24530.000000
# 75%                   24.000000     56958.000000   50809.000000
# max                   31.000000    573925.000000  526009.000000
#
#        processing_fee           gst  net_disbursement  loan_tenure_months  \
# count    37500.000000  37500.000000      37500.000000        37500.000000
# mean       883.197442   7912.214112      35165.396053           25.961040
# std       1244.409539  10636.287340      47272.388178           12.447444
# min          0.000000      0.000000          0.000000            6.000000
# 25%        211.420000   1902.780000       8456.800000           16.000000
# 50%        490.600000   4415.400000      19624.000000           24.000000
# 75%       1016.620000   9145.620000      40647.200000           35.000000
# max      58228.978766  94681.620000     420807.200000           59.000000
#
#        principal_outstanding  bank_balance_at_application  \
# count           37500.000000                 37500.000000
# mean            14672.014664                 10849.287546
# std             13350.418886                 11474.595159
# min                -0.011000                     0.000000
# 25%              4644.172500                  3157.442750
# 50%             10971.702500                  7315.159500
# 75%             19633.669000                 13574.690250
# max             55000.000000                 86313.073000
#
#        number_of_open_accounts  number_of_closed_accounts  total_loan_months  \
# count             37500.000000               37500.000000        37500.00000
# mean                  2.502907                   1.001120           76.11104
# std                   1.119070                   0.814021           43.76852
# min                   1.000000                   0.000000            1.00000
# 25%                   1.000000                   0.000000           42.00000
# 50%                   3.000000                   1.000000           71.00000
# 75%                   4.000000                   2.000000          107.00000
# max                   4.000000                   2.000000          223.00000
#
#        delinquent_months     total_dpd  enquiry_count  \
# count       37500.000000  37500.000000   37500.000000
# mean            4.844853     26.672613       5.008533
# std             5.841396     32.779424       2.029236
# min             0.000000      0.000000       1.000000
# 25%             0.000000      0.000000       4.000000
# 50%             3.000000     13.000000       5.000000
# 75%             8.000000     46.000000       6.000000
# max            24.000000    171.000000       9.000000
#
#        credit_utilization_ratio     gender_M  marital_status_Single  \
# count              37500.000000  37500.00000            37500.00000
# mean                  43.424880      0.60080                0.45040
# std                   29.392857      0.48974                0.49754
# min                    0.000000      0.00000                0.00000
# 25%                   18.000000      0.00000                0.00000
# 50%                   39.000000      1.00000                0.00000
# 75%                   67.000000      1.00000                1.00000
# max                   99.000000      1.00000                1.00000
#
#        employment_status_Self-Employed  residence_type_Owned  \
# count                     37500.000000          37500.000000
# mean                          0.641200              0.563547
# std                           0.479655              0.495952
# min                           0.000000              0.000000
# 25%                           0.000000              0.000000
# 50%                           1.000000              1.000000
# 75%                           1.000000              1.000000
# max                           1.000000              1.000000
#
#        residence_type_Rented  loan_purpose_Education  loan_purpose_Home  \
# count           37500.000000            37500.000000       37500.000000
# mean                0.198987                0.149920           0.301493
# std                 0.399243                0.356998           0.458913
# min                 0.000000                0.000000           0.000000
# 25%                 0.000000                0.000000           0.000000
# 50%                 0.000000                0.000000           0.000000
# 75%                 0.000000                0.000000           1.000000
# max                 1.000000                1.000000           1.000000
#
#        loan_purpose_Personal  loan_type_Unsecured       default
# count           37500.000000         37500.000000  37500.000000
# mean                0.349920             0.349920      0.085947
# std                 0.476951             0.476951      0.280289
# min                 0.000000             0.000000      0.000000
# 25%                 0.000000             0.000000      0.000000
# 50%                 0.000000             0.000000      0.000000
# 75%                 1.000000             1.000000      0.000000
# max                 1.000000             1.000000      1.000000

# %%
df_train.columns
# Out:
# Index(['age', 'income', 'number_of_dependants', 'years_at_current_address',
#        'sanction_amount', 'loan_amount', 'processing_fee', 'gst',
#        'net_disbursement', 'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'gender_M',
#        'marital_status_Single', 'employment_status_Self-Employed',
#        'residence_type_Owned', 'residence_type_Rented',
#        'loan_purpose_Education', 'loan_purpose_Home', 'loan_purpose_Personal',
#        'loan_type_Unsecured', 'default'],
#       dtype='object')

# %%
columns_continuous = [
    'age', 'income', 'number_of_dependants', 'years_at_current_address',
    'sanction_amount', 'loan_amount', 'processing_fee', 'gst',
    'net_disbursement', 'loan_tenure_months', 'principal_outstanding',
    'bank_balance_at_application', 'number_of_open_accounts',
    'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
    'total_dpd', 'enquiry_count', 'credit_utilization_ratio'
]

columns_categorical = [
    'gender_M', 'marital_status_Single', 'employment_status_Self-Employed',
    'residence_type_Owned', 'residence_type_Rented',
    'loan_purpose_Education', 'loan_purpose_Home', 'loan_purpose_Personal',
    'loan_type_Unsecured'
]

# %% [markdown]
# ### ***II.6 Box plot pour visualiser les valeurs aberrantes***

# %%
num_plots = len(columns_continuous)
num_cols = 4  
num_rows = (num_plots + num_cols - 1) // num_cols  

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  
axes = axes.flatten()  

for i, col in enumerate(columns_continuous):
    sns.boxplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col) 
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Les boxplots révèlent des valeurs aberrantes sur plusieurs variables continues :
# #### <p><strong> Variables monétaires fortement impactées :</strong></p>income, sanction_amount, loan_amount, bank_balance_at_application processing_fee, gst et net_disbursement.
# #### <p><strong> Variables de crédit bureau modérément impactées :</strong></p>principal_outstanding, delinquent_months, total_dpd
# #### <p><strong> Variables peu impactées :</strong></p>age, total_loan_months, et les variables discrètes,(number_of_dependants, enquiry_count, etc.) sans outliers détectés.
# #### Ces outliers ou valeurs aberrantes sont probablement réels (gros emprunteurs, hauts revenus)
# #### et non des erreurs de saisie

# %% [markdown]
# ### ***II.7 Histogramme***

# %%
num_plots = len(columns_continuous)
num_cols = 4  
num_rows = (num_plots + num_cols - 1) // num_cols 

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  
axes = axes.flatten()  
for i, col in enumerate(columns_continuous):
    sns.histplot(df_train[col], ax=axes[i])
    axes[i].set_title(col)  


for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Les histogrammes révèlent deux groupes distincts de distributions :
# ##### <p><strong>Distributions symétriques / quasi-normales (skewness ≈ 0) :</strong></p>age, number_of_dependants, years_at_current_address, number_of_open_accounts, number_of_closed_accounts, enquiry_count, credit_utilization_ratio
# ##### <p><strong>Distributions fortement asymétriques à droite :</strong></p>processing_fee (skewness très forte), loan_amount, sanction_amount, net_disbursement, gst (forte), bank_balance_at_application, income (modérée)
# ##### delinquent_months, total_dpd (légère)
# ##### <p><strong>Note :</strong></p>processing_fee, gst et net_disbursement partagent la même distribution que loan_amount car elles en sont dérivées.

# %% [markdown]
# # Analyse de la variable : Processing Fee

# %%
df_train.processing_fee.describe()
# Out:
# count    37500.000000
# mean       883.197442
# std       1244.409539
# min          0.000000
# 25%        211.420000
# 50%        490.600000
# 75%       1016.620000
# max      58228.978766
# Name: processing_fee, dtype: float64

# %% [markdown]
# Les statistiques montrent qu'il n'y a aucune valeur manquante dans processing_fee.
# La distribution est très asymétrique à droite : la majorité des frais est concentrée
# sur de petites valeurs, avec quelques extrêmes très élevés.
# La valeur minimum est 0, certains prêts ne comportant aucun frais de traitement.
# Ces valeurs aberrantes sont probablement réels et non des erreurs de saisie.
# Une transformation log1p est recommandée pour corriger l'asymétrie
# tout en gérant correctement les zéros.

# %%
df_train[(df_train.processing_fee / df_train.loan_amount) > 0.03][["loan_amount", "processing_fee"]]
# Out:
#        loan_amount  processing_fee
# 23981      24574.0    29367.701254
# 28174      10626.0    13359.419404
# 47089      19118.0    20448.612447
# 29305      28776.0    33400.158058
# 9898       39886.0    58228.978766

# %% [markdown]
# #### Ces observations correspondent à des prêts dont les frais de traitement
# #### dépassent 3% du montant emprunté, ce qui est incohérent d'un point de vue métier.
# #### Il s'agit de valeurs aberrantes à exclure avant la modélisation.

# %%
df_train_1 = df_train[df_train.processing_fee / df_train.loan_amount < 0.03].copy()
df_train_1.shape
# Out:
# (37488, 29)

# %%
df_test = df_test[df_test.processing_fee/df_test.loan_amount<0.03].copy()
df_test.shape
# Out:
# (12497, 29)

# %%
df_test_1 = df_test[df_test.processing_fee / df_test.loan_amount < 0.03].copy()

# %% [markdown]
# ### Une transformation log1p sur les variables à forte asymétrie avant modélisation

# %%
cols_to_log = ['processing_fee', 'loan_amount', 'sanction_amount',
               'net_disbursement', 'gst', 'bank_balance_at_application', 'income']
df_train[cols_to_log] = df_train[cols_to_log].apply(np.log1p)

# %% [markdown]
# ### *Utilisation d'autres règles de gestion pour la validation des données*
#
#
#
#
# #### *Règle 1 : la GST ne doit pas être supérieure à 20%.*

# %%
df_train_1[(df_train_1.gst/df_train_1.loan_amount)>0.2].shape
# Out:
# (0, 29)

# %% [markdown]
# #### *Règle 2 : Le décaissement net ne doit pas être supérieur au montant du prêt.*

# %%
df_train_1[df_train_1.net_disbursement>df_train_1.loan_amount].shape
# Out:
# (0, 29)

# %% [markdown]
# Aucune ligne n'a été trouvée qui enfreint les règles 1 et 2.

# %% [markdown]
# # Analyse des colonnes catégorielles

# %%
columns_categorical
# Out:
# ['gender_M',
#  'marital_status_Single',
#  'employment_status_Self-Employed',
#  'residence_type_Owned',
#  'residence_type_Rented',
#  'loan_purpose_Education',
#  'loan_purpose_Home',
#  'loan_purpose_Personal',
#  'loan_type_Unsecured']

# %%
for col in columns_categorical:
    print(col, "-->", df_train_1[col].unique())
# Out:
# gender_M --> [1 0]
# marital_status_Single --> [0 1]
# employment_status_Self-Employed --> [1 0]
# residence_type_Owned --> [1 0]
# residence_type_Rented --> [0 1]
# loan_purpose_Education --> [0 1]
# loan_purpose_Home --> [1 0]
# loan_purpose_Personal --> [0 1]
# loan_type_Unsecured --> [0 1]

# %% [markdown]
# <p style="text-align: center; color: blue; font-size: 28px;"><strong> Analyse exploratoire des données </strong></p>

# %%
columns_continuous
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %% [markdown]
# ## Colonne Age

# %%
df_train_1.groupby("default")['age'].describe()
# Out:
#            count       mean       std   min   25%   50%   75%   max
# default
# 0        34265.0  39.767693  9.880235  18.0  33.0  40.0  46.0  70.0
# 1         3223.0  37.124729  9.290168  18.0  31.0  37.0  44.0  70.0

# %% [markdown]
# * Les clients en défaut sont en moyenne plus jeunes que ceux sans défaut, bien que les distributions d’âge se chevauchent fortement. L’âge peut donc être un facteur explicatif, mais à lui seul, il ne suffit pas pour prédire le défaut.

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['age'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['age'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Densité de l'âge selon la variable de défaut")
plt.legend()
plt.show()

# %% [markdown]
# **Les défauts sont légèrement plus fréquents chez les clients plus jeunes, mais la différence reste modérée.**

# %% [markdown]
# # KDE pour toutes les colones

# %%
plt.figure(figsize=(24, 20))  # Width, height in inches

for i, col in enumerate(columns_continuous):
    plt.subplot(6, 4, i+1)  # 1 row, 4 columns, ith subplot
    sns.kdeplot(df_train_1[col][df_train_1['default']==0], fill=True, label='default=0')
    sns.kdeplot(df_train_1[col][df_train_1['default']==1], fill=True, label='default=1')
    plt.title(col)        
    plt.xlabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Les courbes de densité révèlent trois groupes de variables :
# #### <p><strong>-Forts prédicteurs du défaut</strong></p> (écart marqué entre les deux groupes) :credit_utilization_ratio , total_dpd , delinquent_months
# ####   montrent une séparation claire : plus ces valeurs sont élevées, plus la probabilité de défaut augmente.
# #### Ce sont les variables les plus discriminantes, car elles reflètent directement le comportement de remboursement
# #### et le niveau d'endettement du client.
# #### <p><strong>- Variables monétaires</strong></p> (loan_amount, sanction_amount, processing_fee,gst, net_disbursement) :
# ####    écart apparent (~+41%) mais distributions très chevauchées. Ces variables seules ne traduisent pas réellement
# ####   la capacité de remboursement — un prêt élevé n'est pas nécessairement risqué si le revenu est également élevé.
# ####    Il serait pertinent de créer un ratio Loan-to-Income (LTI) combinant loan_amount et income.
# #### <p><strong>-Faible pouvoir discriminant :</strong></p>age , income , bank_balance_at_application,
# ####   number_of_dependants, years_at_current_address, enquiry_count
# ####   ne montrent pas de différence marquée entre les deux groupes.

# %% [markdown]
# ## Ingénierie des caractéristiques (Feature Engineering)

# %% [markdown]
# **Générer un ratio prêt/revenu (PSR)**

# %%
df_train_1[["loan_amount", "income"]].head(3)
# Out:
#        loan_amount    income
# 12746     257862.0  124597.0
# 32495      12639.0    7865.0
# 43675     124256.0   35145.0

# %%
df_train_1['loan_to_income'] = round(
    df_train_1['loan_amount'] / df_train_1['income'].replace(0, pd.NA), 2)
df_train_1['loan_to_income'].describe()
# Out:
# count    37488.000000
# mean         1.556711
# std          0.973687
# min          0.300000
# 25%          0.770000
# 50%          1.160000
# 75%          2.460000
# max          4.570000
# Name: loan_to_income, dtype: float64

# %%
df_test_1['loan_to_income'] = round(
    df_test_1['loan_amount'] / df_test_1['income'].replace(0, pd.NA), 2)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Densite du ratio Loan-to-Income (LTI) selon le defaut")
plt.legend()
plt.show()

# %% [markdown]
# Le graphique confirme que le ratio Loan-to-Income (LTI) est un bon prédicteur du défaut.
# Les clients sans défaut (default=0) ont une moyenne LTI de 1.50, contre 2.19
# pour les clients en défaut (default=1), soit un écart de +46.5%.
# La courbe default=0 est concentrée sur les faibles valeurs de LTI, reflétant un endettement modéré par rapport au revenu.
# La courbe default=1 est décalée vers la droite avec une queue plus étalée, indiquant que plus le prêt représente une part importante du revenu,plus le risque de défaut est élevé. Le ratio LTI apporte donc une information discriminante que loan_amount et income ne fournissaient pas individuellement.

# %% [markdown]
# **Générer un taux d'impayés**

# %%
df_train_1['delinquency_ratio'] = (df_train_1['delinquent_months'] * 100 / df_train_1['total_loan_months'].replace(0, pd.NA)).round(1)
df_test_1['delinquency_ratio']  = (df_test_1['delinquent_months']  * 100 / df_test_1['total_loan_months'].replace(0, pd.NA)).round(1)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Densité du taux de délinquance selon le défaut")
plt.legend()
plt.show()

# %% [markdown]
# La courbe default=0 est fortement concentrée autour de 0%, indiquant que
# la grande majorité des clients non défaillants ont un taux de retard
# très faible (moyenne : 8.66%).
#
# La courbe default=1 est décalée vers la droite et plus étalée, avec une
# moyenne de 28.11% — soit +225% par rapport aux non-défaillants.
# Plus le taux de retard est élevé, plus le risque de défaut augmente.
# C'est la feature engineerée la plus discriminante du dataset, devant loan_to_income, credit_utilization_ratio,
# total_dpd et delinquent_months.

# %% [markdown]
# # Générer une moyenne de DPD par délinquance

# %%
df_train_1['avg_dpd_per_delinquency'] = np.where(
    df_train_1['delinquent_months'] != 0,
    (df_train_1['total_dpd'] / df_train_1['delinquent_months']).round(1),
    0
)
df_test_1['avg_dpd_per_delinquency'] = np.where(
    df_test_1['delinquent_months'] != 0,
    (df_test_1['total_dpd'] / df_test_1['delinquent_months']).round(1),
    0
)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title("Densité de la gravité moyenne des retards selon le défaut")
plt.legend()
plt.show()

# %% [markdown]
# - Le graphique bleu (default = 0) montre une forte concentration des valeurs autour de 0, indiquant que les clients non défaillants présentent peu ou pas de retard moyen.
# - Le graphique orange (default = 1) est décalé vers des valeurs plus élevées, ce qui reflète des retards plus longs et plus sévères.
# - Le faible chevauchement entre les deux distributions suggère que `avg_dpd_per_delinquency` est une variable fortement discriminante pour la défaillance.

# %% [markdown]
# #### Suppression des colonnes sources utilisées pour le feature engineering
# #### loan_amount et income → remplacées par loan_to_income
# #### total_loan_months et delinquent_months → remplacées par delinquency_ratio
# #### total_dpd et delinquent_months → remplacées par avg_dpd_per_delinquency

# %%
cols_to_drop = ['loan_amount', 'income', 'total_loan_months',
                'delinquent_months', 'total_dpd']

# %%
df_train_2 = df_train_1.drop(cols_to_drop, axis='columns')
df_test_2  = df_test_1.drop(cols_to_drop, axis='columns')
print(df_train_2.columns.tolist())
print()
print(df_train_2.select_dtypes(['int64', 'float64']).columns.tolist())
# Out:
# ['age', 'number_of_dependants', 'years_at_current_address', 'sanction_amount', 'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months', 'principal_outstanding', 'bank_balance_at_application', 'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count', 'credit_utilization_ratio', 'gender_M', 'marital_status_Single', 'employment_status_Self-Employed', 'residence_type_Owned', 'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home', 'loan_purpose_Personal', 'loan_type_Unsecured', 'default', 'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency']
#
# ['age', 'number_of_dependants', 'years_at_current_address', 'sanction_amount', 'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months', 'principal_outstanding', 'bank_balance_at_application', 'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count', 'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency']

# %% [markdown]
# # VIF pour mésurer la multicolinéarité

# %%
from sklearn.preprocessing import MinMaxScaler
# Définition des colonnes continues à normaliser
cols_to_scale = ['age', 'number_of_dependants', 'years_at_current_address',
                 'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
                 'loan_tenure_months', 'principal_outstanding',
                 'bank_balance_at_application', 'number_of_open_accounts',
                 'number_of_closed_accounts', 'enquiry_count',
                 'credit_utilization_ratio', 'loan_to_income',
                 'delinquency_ratio', 'avg_dpd_per_delinquency']
# Séparation X / y
X_train_vif = df_train_2.drop('default', axis='columns').copy()
y_train_vif = df_train_2['default']

# %%
X_test_vif  = df_test_2.drop('default', axis='columns').copy()
y_test_vif  = df_test_2['default']

# %%
# Normalisation MinMaxScaler
scaler = MinMaxScaler()
X_train_vif[cols_to_scale] = scaler.fit_transform(X_train_vif[cols_to_scale])
X_test_vif[cols_to_scale]  = scaler.transform(X_test_vif[cols_to_scale])

X_train_vif.describe()
# Out:
#                 age  number_of_dependants  years_at_current_address  \
# count  37488.000000          37488.000000              37488.000000
# mean       0.414240              0.388903                  0.499918
# std        0.189590              0.307182                  0.297364
# min        0.000000              0.000000                  0.000000
# 25%        0.288462              0.000000                  0.233333
# 50%        0.403846              0.400000                  0.500000
# 75%        0.538462              0.600000                  0.766667
# max        1.000000              1.000000                  1.000000
#
#        sanction_amount  processing_fee           gst  net_disbursement  \
# count     37488.000000    37488.000000  37488.000000      37488.000000
# mean          0.088840        0.082513      0.082513          0.082513
# std           0.120117        0.112480      0.112480          0.112480
# min           0.000000        0.000000      0.000000          0.000000
# 25%           0.020555        0.018963      0.018963          0.018963
# 50%           0.049364        0.045516      0.045516          0.045516
# 75%           0.098027        0.095555      0.095555          0.095555
# max           1.000000        1.000000      1.000000          1.000000
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count        37488.000000           37488.000000                 37488.000000
# mean             0.376631               0.261615                     0.123550
# std              0.234860               0.244461                     0.133275
# min              0.000000               0.000000                     0.000000
# 25%              0.188679               0.077988                     0.034205
# 50%              0.339623               0.193870                     0.082515
# 75%              0.547170               0.352418                     0.155192
# max              1.000000               1.000000                     1.000000
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count             37488.000000                37488.00000   37488.000000
# mean                  0.500925                    0.50056       0.501077
# std                   0.373040                    0.40701       0.253666
# min                   0.000000                    0.00000       0.000000
# 25%                   0.000000                    0.00000       0.375000
# 50%                   0.666667                    0.50000       0.500000
# 75%                   1.000000                    1.00000       0.625000
# max                   1.000000                    1.00000       1.000000
#
#        credit_utilization_ratio      gender_M  marital_status_Single  \
# count              37488.000000  37488.000000           37488.000000
# mean                   0.438653      0.600832               0.450411
# std                    0.296902      0.489734               0.497541
# min                    0.000000      0.000000               0.000000
# 25%                    0.181818      0.000000               0.000000
# 50%                    0.393939      1.000000               0.000000
# 75%                    0.676768      1.000000               1.000000
# max                    1.000000      1.000000               1.000000
#
#        employment_status_Self-Employed  residence_type_Owned  \
# count                     37488.000000          37488.000000
# mean                          0.641165              0.563594
# std                           0.479665              0.495946
# min                           0.000000              0.000000
# 25%                           0.000000              0.000000
# 50%                           1.000000              1.000000
# 75%                           1.000000              1.000000
# max                           1.000000              1.000000
#
#        residence_type_Rented  loan_purpose_Education  loan_purpose_Home  \
# count           37488.000000            37488.000000       37488.000000
# mean                0.198890                0.149915           0.301536
# std                 0.399171                0.356992           0.458931
# min                 0.000000                0.000000           0.000000
# 25%                 0.000000                0.000000           0.000000
# 50%                 0.000000                0.000000           0.000000
# 75%                 0.000000                0.000000           1.000000
# max                 1.000000                1.000000           1.000000
#
#        loan_purpose_Personal  loan_type_Unsecured  loan_to_income  \
# count           37488.000000         37488.000000    37488.000000
# mean                0.349899             0.349899        0.294312
# std                 0.476944             0.476944        0.228030
# min                 0.000000             0.000000        0.000000
# 25%                 0.000000             0.000000        0.110070
# 50%                 0.000000             0.000000        0.201405
# 75%                 1.000000             1.000000        0.505855
# max                 1.000000             1.000000        1.000000
#
#        delinquency_ratio  avg_dpd_per_delinquency
# count       37488.000000             37488.000000
# mean            0.103299                 0.328391
# std             0.172985                 0.290663
# min             0.000000                 0.000000
# 25%             0.000000                 0.000000
# 50%             0.037000                 0.430000
# 75%             0.129000                 0.572500
# max             1.000000                 1.000000

# %%
X_test_vif.describe()
# Out:
#                 age  number_of_dependants  years_at_current_address  \
# count  12497.000000          12497.000000              12497.000000
# mean       0.415001              0.384892                  0.502697
# std        0.188773              0.306871                  0.298103
# min        0.000000              0.000000                  0.000000
# 25%        0.288462              0.000000                  0.233333
# 50%        0.423077              0.400000                  0.500000
# 75%        0.538462              0.600000                  0.766667
# max        1.000000              1.000000                  1.000000
#
#        sanction_amount  processing_fee           gst  net_disbursement  \
# count     12497.000000    12497.000000  12497.000000      12497.000000
# mean          0.089218        0.082800      0.082800          0.082800
# std           0.120844        0.112877      0.112877          0.112877
# min          -0.000019       -0.000126     -0.000126         -0.000126
# 25%           0.020958        0.019387      0.019387          0.019387
# 50%           0.050189        0.046249      0.046249          0.046249
# 75%           0.097422        0.094927      0.094927          0.094927
# max           0.981249        0.963717      0.963717          0.963717
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count        12497.000000           12497.000000                 12497.000000
# mean             0.375092               0.264632                     0.124944
# std              0.233792               0.245290                     0.134708
# min              0.000000               0.000163                     0.000668
# 25%              0.188679               0.079715                     0.034167
# 50%              0.339623               0.198239                     0.084024
# 75%              0.547170               0.356914                     0.157792
# max              1.000000               1.000000                     0.939154
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count             12497.000000               12497.000000   12497.000000
# mean                  0.497293                   0.500440       0.501470
# std                   0.372576                   0.407226       0.253618
# min                   0.000000                   0.000000       0.000000
# 25%                   0.000000                   0.000000       0.375000
# 50%                   0.333333                   0.500000       0.500000
# 75%                   0.666667                   1.000000       0.625000
# max                   1.000000                   1.000000       1.000000
#
#        credit_utilization_ratio      gender_M  marital_status_Single  \
# count              12497.000000  12497.000000           12497.000000
# mean                   0.436038      0.596623               0.452909
# std                    0.295418      0.490595               0.497797
# min                    0.000000      0.000000               0.000000
# 25%                    0.181818      0.000000               0.000000
# 50%                    0.393939      1.000000               0.000000
# 75%                    0.676768      1.000000               1.000000
# max                    1.000000      1.000000               1.000000
#
#        employment_status_Self-Employed  residence_type_Owned  \
# count                     12497.000000          12497.000000
# mean                          0.651116              0.568536
# std                           0.476636              0.495300
# min                           0.000000              0.000000
# 25%                           0.000000              0.000000
# 50%                           1.000000              1.000000
# 75%                           1.000000              1.000000
# max                           1.000000              1.000000
#
#        residence_type_Rented  loan_purpose_Education  loan_purpose_Home  \
# count           12497.000000            12497.000000       12497.000000
# mean                0.193486                0.154757           0.297751
# std                 0.395047                0.361687           0.457288
# min                 0.000000                0.000000           0.000000
# 25%                 0.000000                0.000000           0.000000
# 50%                 0.000000                0.000000           0.000000
# 75%                 0.000000                0.000000           1.000000
# max                 1.000000                1.000000           1.000000
#
#        loan_purpose_Personal  loan_type_Unsecured  loan_to_income  \
# count           12497.000000         12497.000000    12497.000000
# mean                0.348564             0.348564        0.293038
# std                 0.476535             0.476535        0.226176
# min                 0.000000             0.000000        0.000000
# 25%                 0.000000             0.000000        0.112412
# 50%                 0.000000             0.000000        0.201405
# 75%                 1.000000             1.000000        0.498829
# max                 1.000000             1.000000        1.004684
#
#        delinquency_ratio  avg_dpd_per_delinquency
# count       12497.000000             12497.000000
# mean            0.106074                 0.333844
# std             0.173081                 0.289680
# min             0.000000                 0.000000
# 25%             0.000000                 0.000000
# 50%             0.042000                 0.440000
# 75%             0.134000                 0.580000
# max             1.000000                 1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]
    return vif_df

# %%
X_train_vif.head(4)
# Out:
#             age  number_of_dependants  years_at_current_address  \
# 12746  0.788462                   0.6                  0.966667
# 32495  0.500000                   0.0                  0.866667
# 43675  0.384615                   0.0                  0.833333
# 9040   0.461538                   0.4                  0.966667
#
#        sanction_amount  processing_fee       gst  net_disbursement  \
# 12746         0.634301        0.489626  0.489626          0.489626
# 32495         0.021170        0.022884  0.022884          0.022884
# 43675         0.217588        0.235329  0.235329          0.235329
# 9040          0.043452        0.034315  0.034315          0.034315
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# 12746            0.415094               1.000000                     0.613386
# 32495            0.830189               0.087020                     0.025205
# 43675            0.490566               0.326615                     0.174318
# 9040             0.641509               0.199051                     0.077523
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# 12746                 1.000000                        1.0          0.375
# 32495                 0.666667                        0.5          0.500
# 43675                 0.000000                        0.5          0.375
# 9040                  0.666667                        0.0          0.875
#
#        credit_utilization_ratio  gender_M  marital_status_Single  \
# 12746                  0.363636         1                      0
# 32495                  0.050505         0                      1
# 43675                  0.000000         1                      1
# 9040                   0.878788         1                      0
#
#        employment_status_Self-Employed  residence_type_Owned  \
# 12746                                1                     1
# 32495                                0                     1
# 43675                                0                     0
# 9040                                 0                     0
#
#        residence_type_Rented  loan_purpose_Education  loan_purpose_Home  \
# 12746                      0                       0                  1
# 32495                      0                       1                  0
# 43675                      0                       0                  1
# 9040                       0                       1                  0
#
#        loan_purpose_Personal  loan_type_Unsecured  loan_to_income  \
# 12746                      0                    0        0.414520
# 32495                      0                    0        0.306792
# 43675                      0                    0        0.758782
# 9040                       0                    0        0.194379
#
#        delinquency_ratio  avg_dpd_per_delinquency
# 12746              0.132                     0.59
# 32495              0.062                     0.62
# 43675              0.222                     0.56
# 9040               0.000                     0.00

# %%
calculate_vif(X_train_vif[cols_to_scale])
# Out:
# C:\Users\Hassan\anaconda3\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                          Column         VIF
# 0                           age    5.554651
# 1          number_of_dependants    2.723497
# 2      years_at_current_address    3.360912
# 3               sanction_amount  101.084280
# 4                processing_fee         inf
# 5                           gst         inf
# 6              net_disbursement         inf
# 7            loan_tenure_months    6.170225
# 8         principal_outstanding   16.316537
# 9   bank_balance_at_application    9.325626
# 10      number_of_open_accounts    4.379969
# 11    number_of_closed_accounts    2.364971
# 12                enquiry_count    6.333218
# 13     credit_utilization_ratio    2.895620
# 14               loan_to_income    6.893445
# 15            delinquency_ratio    1.930878
# 16      avg_dpd_per_delinquency    2.903373

# %% [markdown]
# Les résultats du VIF indiquent une multicolinéarité sévère, notamment entre les variables financières liées au montant du prêt (certaines avec un VIF infini).
# *Cela nous amène à supprimer les valeurs redondantes.*
#
# A l'exemple du processing_fee, gst, net_disbursement, ces colonnes sont des dérivées directes de loan_amount
# Elles n'apportent aucune information supplémentaire au modèle.

# %%
# Suppression des colonnes à VIF infini et VIF très élevé
cols_to_drop_vif = ['processing_fee', 'gst', 'net_disbursement',
                    'sanction_amount', 'principal_outstanding']

X_train_vif = X_train_vif.drop(cols_to_drop_vif, axis='columns', errors='ignore')
X_test_vif  = X_test_vif.drop(cols_to_drop_vif, axis='columns', errors='ignore')

# Mise à jour de cols_to_scale
cols_to_scale = [c for c in cols_to_scale if c not in cols_to_drop_vif]

# Nouveau calcul VIF
calculate_vif(X_train_vif[cols_to_scale])
# Out:
#                          Column       VIF
# 0                           age  5.265859
# 1          number_of_dependants  2.719203
# 2      years_at_current_address  3.336810
# 3            loan_tenure_months  6.005479
# 4   bank_balance_at_application  1.798157
# 5       number_of_open_accounts  4.346294
# 6     number_of_closed_accounts  2.350572
# 7                 enquiry_count  6.300588
# 8      credit_utilization_ratio  2.878920
# 9                loan_to_income  4.537891
# 10            delinquency_ratio  1.929426
# 11      avg_dpd_per_delinquency  2.900313

# %% [markdown]
# ### Les valeurs du VIF sont globalement inférieures à 10
# Ce qui indique l’absence de multicolinéarité sévère dans le modèle.
# Certaines variables présentent une corrélation modérée (VIF entre 5 et 6.3), mais la situation reste acceptable pour l’estimation.

# %%
corr = X_train_vif[cols_to_scale].corr().abs()
corr
# Out:
#                                   age  number_of_dependants  \
# age                          1.000000              0.253004
# number_of_dependants         0.253004              1.000000
# years_at_current_address     0.001310              0.013521
# loan_tenure_months           0.004917              0.007240
# bank_balance_at_application  0.028466              0.009366
# number_of_open_accounts      0.002756              0.001735
# number_of_closed_accounts    0.005536              0.003577
# enquiry_count                0.000918              0.004270
# credit_utilization_ratio     0.004269              0.008266
# loan_to_income               0.172861              0.033960
# delinquency_ratio            0.000802              0.002756
# avg_dpd_per_delinquency      0.011486              0.011802
#
#                              years_at_current_address  loan_tenure_months  \
# age                                          0.001310            0.004917
# number_of_dependants                         0.013521            0.007240
# years_at_current_address                     1.000000            0.000336
# loan_tenure_months                           0.000336            1.000000
# bank_balance_at_application                  0.001714            0.002959
# number_of_open_accounts                      0.001450            0.008409
# number_of_closed_accounts                    0.001418            0.004835
# enquiry_count                                0.000182            0.003635
# credit_utilization_ratio                     0.007135            0.005131
# loan_to_income                               0.002036            0.635631
# delinquency_ratio                            0.002973            0.000693
# avg_dpd_per_delinquency                      0.004722            0.001280
#
#                              bank_balance_at_application  \
# age                                             0.028466
# number_of_dependants                            0.009366
# years_at_current_address                        0.001714
# loan_tenure_months                              0.002959
# bank_balance_at_application                     1.000000
# number_of_open_accounts                         0.001198
# number_of_closed_accounts                       0.002652
# enquiry_count                                   0.002680
# credit_utilization_ratio                        0.002602
# loan_to_income                                  0.037708
# delinquency_ratio                               0.007779
# avg_dpd_per_delinquency                         0.006017
#
#                              number_of_open_accounts  \
# age                                         0.002756
# number_of_dependants                        0.001735
# years_at_current_address                    0.001450
# loan_tenure_months                          0.008409
# bank_balance_at_application                 0.001198
# number_of_open_accounts                     1.000000
# number_of_closed_accounts                   0.001409
# enquiry_count                               0.542579
# credit_utilization_ratio                    0.008914
# loan_to_income                              0.002256
# delinquency_ratio                           0.324134
# avg_dpd_per_delinquency                     0.004632
#
#                              number_of_closed_accounts  enquiry_count  \
# age                                           0.005536       0.000918
# number_of_dependants                          0.003577       0.004270
# years_at_current_address                      0.001418       0.000182
# loan_tenure_months                            0.004835       0.003635
# bank_balance_at_application                   0.002652       0.002680
# number_of_open_accounts                       0.001409       0.542579
# number_of_closed_accounts                     1.000000       0.005775
# enquiry_count                                 0.005775       1.000000
# credit_utilization_ratio                      0.010799       0.007859
# loan_to_income                                0.005018       0.000642
# delinquency_ratio                             0.004425       0.178095
# avg_dpd_per_delinquency                       0.000131       0.002778
#
#                              credit_utilization_ratio  loan_to_income  \
# age                                          0.004269        0.172861
# number_of_dependants                         0.008266        0.033960
# years_at_current_address                     0.007135        0.002036
# loan_tenure_months                           0.005131        0.635631
# bank_balance_at_application                  0.002602        0.037708
# number_of_open_accounts                      0.008914        0.002256
# number_of_closed_accounts                    0.010799        0.005018
# enquiry_count                                0.007859        0.000642
# credit_utilization_ratio                     1.000000        0.008954
# loan_to_income                               0.008954        1.000000
# delinquency_ratio                            0.000621        0.004726
# avg_dpd_per_delinquency                      0.003286        0.003687
#
#                              delinquency_ratio  avg_dpd_per_delinquency
# age                                   0.000802                 0.011486
# number_of_dependants                  0.002756                 0.011802
# years_at_current_address              0.002973                 0.004722
# loan_tenure_months                    0.000693                 0.001280
# bank_balance_at_application           0.007779                 0.006017
# number_of_open_accounts               0.324134                 0.004632
# number_of_closed_accounts             0.004425                 0.000131
# enquiry_count                         0.178095                 0.002778
# credit_utilization_ratio              0.000621                 0.003286
# loan_to_income                        0.004726                 0.003687
# delinquency_ratio                     1.000000                 0.451454
# avg_dpd_per_delinquency               0.451454                 1.000000

# %%
high_corr = corr[corr > 0.95]
high_corr
# Out:
#                              age  number_of_dependants  \
# age                          1.0                   NaN
# number_of_dependants         NaN                   1.0
# years_at_current_address     NaN                   NaN
# loan_tenure_months           NaN                   NaN
# bank_balance_at_application  NaN                   NaN
# number_of_open_accounts      NaN                   NaN
# number_of_closed_accounts    NaN                   NaN
# enquiry_count                NaN                   NaN
# credit_utilization_ratio     NaN                   NaN
# loan_to_income               NaN                   NaN
# delinquency_ratio            NaN                   NaN
# avg_dpd_per_delinquency      NaN                   NaN
#
#                              years_at_current_address  loan_tenure_months  \
# age                                               NaN                 NaN
# number_of_dependants                              NaN                 NaN
# years_at_current_address                          1.0                 NaN
# loan_tenure_months                                NaN                 1.0
# bank_balance_at_application                       NaN                 NaN
# number_of_open_accounts                           NaN                 NaN
# number_of_closed_accounts                         NaN                 NaN
# enquiry_count                                     NaN                 NaN
# credit_utilization_ratio                          NaN                 NaN
# loan_to_income                                    NaN                 NaN
# delinquency_ratio                                 NaN                 NaN
# avg_dpd_per_delinquency                           NaN                 NaN
#
#                              bank_balance_at_application  \
# age                                                  NaN
# number_of_dependants                                 NaN
# years_at_current_address                             NaN
# loan_tenure_months                                   NaN
# bank_balance_at_application                          1.0
# number_of_open_accounts                              NaN
# number_of_closed_accounts                            NaN
# enquiry_count                                        NaN
# credit_utilization_ratio                             NaN
# loan_to_income                                       NaN
# delinquency_ratio                                    NaN
# avg_dpd_per_delinquency                              NaN
#
#                              number_of_open_accounts  \
# age                                              NaN
# number_of_dependants                             NaN
# years_at_current_address                         NaN
# loan_tenure_months                               NaN
# bank_balance_at_application                      NaN
# number_of_open_accounts                          1.0
# number_of_closed_accounts                        NaN
# enquiry_count                                    NaN
# credit_utilization_ratio                         NaN
# loan_to_income                                   NaN
# delinquency_ratio                                NaN
# avg_dpd_per_delinquency                          NaN
#
#                              number_of_closed_accounts  enquiry_count  \
# age                                                NaN            NaN
# number_of_dependants                               NaN            NaN
# years_at_current_address                           NaN            NaN
# loan_tenure_months                                 NaN            NaN
# bank_balance_at_application                        NaN            NaN
# number_of_open_accounts                            NaN            NaN
# number_of_closed_accounts                          1.0            NaN
# enquiry_count                                      NaN            1.0
# credit_utilization_ratio                           NaN            NaN
# loan_to_income                                     NaN            NaN
# delinquency_ratio                                  NaN            NaN
# avg_dpd_per_delinquency                            NaN            NaN
#
#                              credit_utilization_ratio  loan_to_income  \
# age                                               NaN             NaN
# number_of_dependants                              NaN             NaN
# years_at_current_address                          NaN             NaN
# loan_tenure_months                                NaN             NaN
# bank_balance_at_application                       NaN             NaN
# number_of_open_accounts                           NaN             NaN
# number_of_closed_accounts                         NaN             NaN
# enquiry_count                                     NaN             NaN
# credit_utilization_ratio                          1.0             NaN
# loan_to_income                                    NaN             1.0
# delinquency_ratio                                 NaN             NaN
# avg_dpd_per_delinquency                           NaN             NaN
#
#                              delinquency_ratio  avg_dpd_per_delinquency
# age                                        NaN                      NaN
# number_of_dependants                       NaN                      NaN
# years_at_current_address                   NaN                      NaN
# loan_tenure_months                         NaN                      NaN
# bank_balance_at_application                NaN                      NaN
# number_of_open_accounts                    NaN                      NaN
# number_of_closed_accounts                  NaN                      NaN
# enquiry_count                              NaN                      NaN
# credit_utilization_ratio                   NaN                      NaN
# loan_to_income                             NaN                      NaN
# delinquency_ratio                          1.0                      NaN
# avg_dpd_per_delinquency                    NaN                      1.0

# %% [markdown]
# ## Résultat excellent
# Aucune paire de variables n'a une corrélation > 0.95 (hors diagonale), seule la diagonale affiche 1.0 (chaque variable avec elle-même).
#
# Tout le reste est NaN ce qui signifie corrélation ≤ 0.95.

# %%
# Sauvegarde des résultats VIF
vif_df = calculate_vif(X_train_vif[cols_to_scale])
selected_numeric_features_vif = vif_df['Column'].values
print(selected_numeric_features_vif)

# Heatmap de corrélation
cols_for_heatmap = list(cols_to_scale) + ['default']
# Out:
# ['age' 'number_of_dependants' 'years_at_current_address'
#  'loan_tenure_months' 'bank_balance_at_application'
#  'number_of_open_accounts' 'number_of_closed_accounts' 'enquiry_count'
#  'credit_utilization_ratio' 'loan_to_income' 'delinquency_ratio'
#  'avg_dpd_per_delinquency']

# %%
plt.figure(figsize=(12, 12))
cm = df_train_2[cols_for_heatmap].corr()
sns.heatmap(cm, annot=True, fmt='.2f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Sélection de caractéristiques : Caractéristiques catégorielles

# %%
X_train_1 = X_train_vif.copy()
X_test_1  = X_test_vif.copy()

# %% [markdown]
# # Calcul du WOE et IV

# %% [markdown]
# *WOE (Weight of Evidence) : mesure le pouvoir de séparation d’une modalité d’une variable par rapport à la cible.*
#
# *IV (Information Value) : mesure la capacité prédictive globale d’une variable*

# %%
# Fonction pour calculer le WOE (Weight of Evidence)
# et l'IV (Information Value) d'une variable
def calculate_woe_iv(df, feature, target):
    
    # 1️⃣ Regrouper les données par modalité de la variable
    # Pour les dummies : 2 modalités (0 et 1)
    # Pour les numériques : modalités = bins après qcut
    grouped = df.groupby(feature)[target].agg(['count', 'sum'])
    
    # 2️⃣ Renommer les colonnes
    # default=1 → défaillants = BAD
    # default=0 → non-défaillants = GOOD
    grouped = grouped.rename(columns={
        'count': 'total',
        'sum': 'bad'
    })
    
    # 3️⃣ Calculer le nombre de "good" (non-défaillants)
    grouped['good'] = grouped['total'] - grouped['bad']
    
    # 4️⃣ Totaux globaux
    total_good = grouped['good'].sum()
    total_bad  = grouped['bad'].sum()
    
    # 5️⃣ Proportions — epsilon pour éviter toute division par zéro
    eps = 1e-6
    grouped['good_pct'] = (grouped['good'] + eps) / (total_good + eps)
    grouped['bad_pct']  = (grouped['bad']  + eps) / (total_bad  + eps)
    
    # 6️⃣ WOE = ln(%good / %bad)
    # WOE > 0 → modalité avec plus de good que de bad → faible risque
    # WOE < 0 → modalité avec plus de bad que de good → fort risque
    grouped['woe'] = np.log(grouped['good_pct'] / grouped['bad_pct'])
    
    # 7️⃣ IV par modalité = (%good - %bad) * WOE
    grouped['iv'] = (grouped['good_pct'] - grouped['bad_pct']) * grouped['woe']
    
    # 8️⃣ Nettoyage des infinis (sécurité supplémentaire)
    grouped['woe'] = grouped['woe'].replace([np.inf, -np.inf], 0)
    grouped['iv']  = grouped['iv'].replace([np.inf, -np.inf], 0)
    
    # 9️⃣ IV total de la variable
    # < 0.02  → ❌ Inutile
    # 0.02–0.1 → ⚠️ Faible
    # 0.1–0.3  → ✅ Moyen
    # > 0.3    → ✅✅ Fort
    total_iv = grouped['iv'].sum()
    
    return grouped, total_iv

# %% [markdown]
# ### y_train converti en int (True/False → 1/0)

# %%
df_woe = pd.concat([X_train_1, y_train.astype(int)], axis=1)

# %% [markdown]
# ### IV pour la variable loan_purpose_Personal sur la variable cible default

# %%
grouped, total_iv = calculate_woe_iv(df_woe, 'loan_purpose_Personal', 'default')

print("Information Value (IV) total :", round(total_iv, 4))
grouped
# Out:
# Information Value (IV) total : 0.1632
#                        total   bad   good  good_pct  bad_pct       woe  \
# loan_purpose_Personal
# 0                      24371  2620  21751  0.634788 0.812907 -0.247326
# 1                      13117   603  12514  0.365212 0.187093  0.668874
#
#                             iv
# loan_purpose_Personal
# 0                     0.044054
# 1                     0.119140

# %% [markdown]
# ### Résultat : IV = 0.1632
# Pouvoir prédictif MOYEN (0.1 < IV < 0.3)

# %% [markdown]
# ### Calcul IV pour toutes les variables

# %%
iv_values = {}
df_woe_full = pd.concat([X_train_1, y_train.astype(int)], axis=1)

for feature in X_train_1.columns:
    try:
        if X_train_1[feature].nunique() <= 2:
            # Variable binaire (dummy 0/1) → WOE direct
            _, iv = calculate_woe_iv(df_woe_full, feature, 'default')
        else:
            # Variable numérique continue → discrétisation en déciles
            X_binned = pd.qcut(
                X_train_1[feature], q=10, labels=False, duplicates='drop'
            )
            df_binned = pd.concat(
                [X_binned.rename(feature), y_train.astype(int)], axis=1
            )
            _, iv = calculate_woe_iv(df_binned, feature, 'default')

        iv_values[feature] = iv

    except Exception as e:
        print(f"⚠️ Erreur sur {feature} : {e}")
        iv_values[feature] = 0
pd.set_option('display.float_format', lambda x: f'{x:.6f}')

iv_df = pd.DataFrame(
    list(iv_values.items()),
    columns=['Feature', 'IV']
).sort_values('IV', ascending=False).reset_index(drop=True)

iv_df
# Out:
#                             Feature       IV
# 0          credit_utilization_ratio 2.347201
# 1                 delinquency_ratio 0.692358
# 2                    loan_to_income 0.479844
# 3           avg_dpd_per_delinquency 0.326182
# 4                 loan_purpose_Home 0.284662
# 5                loan_tenure_months 0.233845
# 6             residence_type_Rented 0.196018
# 7              residence_type_Owned 0.191480
# 8               loan_type_Unsecured 0.163193
# 9             loan_purpose_Personal 0.163193
# 10                              age 0.084413
# 11          number_of_open_accounts 0.050278
# 12      bank_balance_at_application 0.011521
# 13                    enquiry_count 0.005904
# 14           loan_purpose_Education 0.004924
# 15  employment_status_Self-Employed 0.003953
# 16         years_at_current_address 0.002247
# 17             number_of_dependants 0.001783
# 18        number_of_closed_accounts 0.001156
# 19            marital_status_Single 0.001130
# 20                         gender_M 0.000474

# %% [markdown]
# - Ce script permet de mesurer le **pouvoir prédictif (Information Value – IV)** de chaque variable du jeu de données `X_train_1`.
# - Les variables **catégorielles** (type `object`) sont traitées directement.
# - Les variables **numériques** sont d’abord **discrétisées en classes** avant le calcul de l’IV.
# - Le résultat final est stocké dans le dictionnaire **`iv_values`**, associant chaque variable à son IV global.

# %% [markdown]
# #### **On selectionne  les variables explicatives** dont l’**Information Value (IV)** est **supérieure à 0.02**.

# %%
selected_features_iv = [feature for feature, iv in iv_values.items() if iv > 0.02]

print(f"{len(selected_features_iv)} variables retenues sur {len(iv_values)} :")
print(selected_features_iv)
# Out:
# 12 variables retenues sur 21 :
# ['age', 'loan_tenure_months', 'number_of_open_accounts', 'credit_utilization_ratio', 'residence_type_Owned', 'residence_type_Rented', 'loan_purpose_Home', 'loan_purpose_Personal', 'loan_type_Unsecured', 'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency']

# %% [markdown]
# # Encodage des caractéristiques

# %%
X_train_reduced = X_train_1[selected_features_iv]
X_test_reduced  = X_test_1[selected_features_iv]

# %%
# Renommage pour cohérence avec la suite du pipeline
X_train_encoded = X_train_reduced.copy()
X_test_encoded  = X_test_reduced.copy()

# %%
X_train_encoded.head(5)
# Out:
#            age  loan_tenure_months  number_of_open_accounts  \
# 12746 0.788462            0.415094                 1.000000
# 32495 0.500000            0.830189                 0.666667
# 43675 0.384615            0.490566                 0.000000
# 9040  0.461538            0.641509                 0.666667
# 13077 0.769231            0.169811                 0.000000
#
#        credit_utilization_ratio  residence_type_Owned  residence_type_Rented  \
# 12746                  0.363636                     1                      0
# 32495                  0.050505                     1                      0
# 43675                  0.000000                     0                      0
# 9040                   0.878788                     0                      0
# 13077                  0.717172                     1                      0
#
#        loan_purpose_Home  loan_purpose_Personal  loan_type_Unsecured  \
# 12746                  1                      0                    0
# 32495                  0                      0                    0
# 43675                  1                      0                    0
# 9040                   0                      0                    0
# 13077                  0                      1                    1
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746        0.414520           0.132000                 0.590000
# 32495        0.306792           0.062000                 0.620000
# 43675        0.758782           0.222000                 0.560000
# 9040         0.194379           0.000000                 0.000000
# 13077        0.046838           0.000000                 0.000000

# %%
X_test_encoded.head(5)
# Out:
#            age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346154            0.754717                 0.333333
# 15514 0.480769            0.226415                 1.000000
# 30367 0.230769            0.547170                 0.666667
# 35347 0.365385            0.754717                 1.000000
# 41814 0.576923            0.716981                 0.666667
#
#        credit_utilization_ratio  residence_type_Owned  residence_type_Rented  \
# 19205                  0.989899                     1                      0
# 15514                  0.323232                     1                      0
# 30367                  0.828283                     1                      0
# 35347                  0.484848                     1                      0
# 41814                  0.979798                     0                      0
#
#        loan_purpose_Home  loan_purpose_Personal  loan_type_Unsecured  \
# 19205                  1                      0                    0
# 15514                  0                      0                    0
# 30367                  0                      0                    0
# 35347                  1                      0                    0
# 41814                  1                      0                    0
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 19205        0.550351           0.000000                 0.000000
# 15514        0.220141           0.000000                 0.000000
# 30367        0.180328           0.000000                 0.000000
# 35347        0.571429           0.024000                 0.700000
# 41814        0.407494           0.107000                 0.640000

# %% [markdown]
# <p style="text-align: center; color: blue; font-size: 28px;"><strong> Entrainement du modèle </strong></p>

# %% [markdown]
# ## *Tentative1*

# %% [markdown]
# #### *Régression logistique, RandomForest et XGB*
# #### *Pas de traitement du déséquilibre des classes*

# %%
# ── Vérification des tailles ──────────────────────────────
print("X_train_encoded :", X_train_encoded.shape)
print("y_train         :", y_train.shape)
print("X_test_encoded  :", X_test_encoded.shape)
print("y_test          :", y_test.shape)
# Out:
# X_train_encoded : (37488, 12)
# y_train         : (37488,)
# X_test_encoded  : (12497, 12)
# y_test          : (12497,)

# %%
y_train = y_train.loc[X_train_encoded.index]
y_test  = y_test.loc[X_test_encoded.index]

print("Après correction :")
print("X_train_encoded :", X_train_encoded.shape)
print("y_train         :", y_train.shape)
print("X_test_encoded  :", X_test_encoded.shape)
print("y_test          :", y_test.shape)
# Out:
# Après correction :
# X_train_encoded : (37488, 12)
# y_train         : (37488,)
# X_test_encoded  : (12497, 12)
# y_test          : (12497,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.72      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# ###  Résultats — Régression Logistique (sans traitement déséquilibre)
# ### ──────────────────────────────────────────────────────────────────
# ####  Classe 0 (non-défaut) — très bien détectée :
# ####    → Précision 0.97 | Rappel 0.99 | F1 0.98
# ####    → Le modèle identifie quasi parfaitement les bons payeurs
# ####   Classe 1 (défaut) — moins bien détectée :
# ####    → Précision 0.85 | Rappel 0.72 | F1 0.78
# ####    → Le modèle rate 28% des défauts (faux négatifs)
# ####    → Problématique en credit scoring : un défaut non détecté = perte financière
# ####  Déséquilibre des classes visible :
# ####    → 11 423 non-défauts (classe 0) vs 1 074 défauts (classe 1)
# ####    → Ratio ≈ 91% / 9% → classes très déséquilibrées
# ####  Accuracy globale de 96% trompeuse :
# ####    → Portée par la classe majoritaire (classe 0)
# ####    → F1-score de la classe 1 (0.78) est la métrique à surveiller

# %%
# Importance des variables — Régression Logistique 
# Les coefficients indiquent le sens et la force de l'impact
# de chaque variable sur la probabilité de défaut :
# → Coefficient positif : augmente le risque de défaut
# → Coefficient négatif : diminue le risque de défaut

feature_importance = model.coef_[0]

coef_df = pd.DataFrame(
    feature_importance,
    index=X_train_encoded.columns,
    columns=['Coefficients']
).sort_values(by='Coefficients', ascending=True)

plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.axvline(x=0, color='black', linestyle='--', linewidth=0.8)
plt.xlabel('Valeur du coefficient')
plt.title('Importance des variables - Régression logistique')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔴 Variables augmentant le risque de défaut (coefficients positifs) :
#    → credit_utilization_ratio : variable la plus impactante
#
#    → loan_to_income           : ratio endettement/revenu élevé = risque élevé
#
#    → delinquency_ratio        : historique de retards = fort signal de défaut
# ### 🟢 Variables réduisant le risque de défaut (coefficients négatifs) :
#    → loan_purpose_Home        : prêt immobilier = profil plus fiable
#
#    → residence_type_Owned     : propriétaire = stabilité financière
#
#    → age                      : légèrement protecteur (client plus mature)

# %% [markdown]
# #### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(n_estimators=100, random_state=42)
model_rf.fit(X_train_encoded, y_train)

y_pred_rf = model_rf.predict(X_test_encoded)

print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.72      0.78      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.97      0.96     12497

# %% [markdown]
# ##### XGBClassifier

# %%
from xgboost import XGBClassifier

model_xgb = XGBClassifier(random_state=42, eval_metric='logloss')
model_xgb.fit(X_train_encoded, y_train)

y_pred_xgb = model_xgb.predict(X_test_encoded)

print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.82      0.75      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.87      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# *Comme il n'y a pas beaucoup de différence entre XGB et LogisticRegression, nous choisirons LogisticRegression comme candidat pour notre candidat RandomizedSearchCV, car il a une meilleure interprétation.*

# %% [markdown]
# # Tentative 1:Logistic Regression

# %%
# Régression Logistique + RandomizedSearchCV
# Pas de traitement du déséquilibre des classes

from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import numpy as np

# Grille des hyperparamètres à tester
param_dist = {
    'C': np.logspace(-4, 4, 20),          # Régularisation : de très forte (10^-4) à très faible (10^4)
    'solver': ['lbfgs', 'saga',
               'liblinear', 'newton-cg']  # Algorithmes d'optimisation
}

log_reg = LogisticRegression(max_iter=10000)  # max_iter élevé pour assurer la convergence

random_search = RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=50,          # 50 combinaisons testées parmi toutes les possibilités
    scoring='f1',       # F1-score classe 1 (défaut) — métrique prioritaire
    cv=3,               # Validation croisée 3 folds
    verbose=2,
    random_state=42,
    n_jobs=-1           # Tous les cœurs disponibles
)

random_search.fit(X_train_encoded, y_train)

print(f"Meilleurs paramètres : {random_search.best_params_}")
print(f"Meilleur score F1    : {random_search.best_score_:.4f}")

# Meilleur modèle
best_model_logistic = random_search.best_estimator_

# Prédiction
y_pred = best_model_logistic.predict(X_test_encoded)

print("\nRapport de classification :")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Meilleurs paramètres : {'solver': 'lbfgs', 'C': 1438.44988828766}
# Meilleur score F1    : 0.7587
#
# Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.83      0.73      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# #### → L'optimisation des hyperparamètres seule ne suffit pas
# #### → Le déséquilibre des classes (91% / 9%) reste le vrai problème à traiter

# %% [markdown]
# # RandomizedSearch CV pour tentative 1: XGBoost

# %%
# XGBoost + RandomizedSearchCV
# Pas de traitement du déséquilibre des classes

from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier

param_dist = {
    'n_estimators'     : [100, 150, 200, 250, 300],
    'max_depth'        : [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate'    : [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample'        : [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree' : [0.6, 0.7, 0.8, 0.9, 1.0],
    'reg_alpha'        : [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # Régularisation L1
    'reg_lambda'       : [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]   # Régularisation L2
}

xgb = XGBClassifier(random_state=42, eval_metric='logloss')

random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dist,
    n_iter=100,       # 100 combinaisons testées
    scoring='f1',     # Optimisation sur F1 classe 1 (défaut)
    cv=3,
    verbose=1,
    n_jobs=-1,
    random_state=42
)

random_search.fit(X_train_encoded, y_train)

print(f"Meilleurs paramètres : {random_search.best_params_}")
print(f"Meilleur score F1    : {random_search.best_score_:.4f}")

best_model_xgb = random_search.best_estimator_

y_pred_xgb_tuned = best_model_xgb.predict(X_test_encoded)

print("\nRapport de classification :")
print(classification_report(y_test, y_pred_xgb_tuned))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Meilleurs paramètres : {'subsample': 0.7, 'reg_lambda': 0.1, 'reg_alpha': 10.0, 'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.2, 'colsample_bytree': 0.9}
# Meilleur score F1    : 0.7803
#
# Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.81      0.77      0.79      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.87      0.89     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# # Tentative 2

# %% [markdown]
# *Régression logistique et XGB*

# %% [markdown]
# *Traiter le déséquilibre des classes à l'aide d'un sous-échantillonnage*

# %%
# Installation de imbalanced-learn
# !pip install imbalanced-learn --break-system-packages
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\hassan\anaconda3\lib\site-packages (0.12.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\hassan\anaconda3\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\hassan\anaconda3\lib\site-packages (from imbalanced-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\hassan\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hassan\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hassan\anaconda3\lib\site-packages (from imbalanced-learn) (3.5.0)

# %%
# Régression Logistique et XGBoost
# Sous-échantillonnage — RandomUnderSampler
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=42)
X_train_res, y_train_res = rus.fit_resample(X_train_encoded, y_train)

print("Distribution après sous-échantillonnage :")
print(y_train_res.value_counts())
print(f"\nTaille avant : {X_train_encoded.shape[0]} lignes")
print(f"Taille après : {X_train_res.shape[0]} lignes")
# Out:
# Distribution après sous-échantillonnage :
# default
# 0    3223
# 1    3223
# Name: count, dtype: int64
#
# Taille avant : 37488 lignes
# Taille après : 6446 lignes

# %% [markdown]
# ## Le module ne peut pas être installé à cause des permissions

# %% [markdown]
# #### UNE ALTERNATIVE MANUELLE

# %%
# Séparer les deux classes
X_train_majority = X_train_encoded[y_train == 0]
X_train_minority = X_train_encoded[y_train == 1]
y_train_majority = y_train[y_train == 0]
y_train_minority = y_train[y_train == 1]

# %%
# Sous-échantillonner la classe majoritaire → même taille que la minoritaire
X_train_majority_res = X_train_majority.sample(n=len(X_train_minority), random_state=42)
y_train_majority_res = y_train_majority.loc[X_train_majority_res.index]

# %%
# Fusionner et mélanger
X_train_res = pd.concat([X_train_majority_res, X_train_minority]).sample(frac=1, random_state=42)
y_train_res = pd.concat([y_train_majority_res, y_train_minority]).loc[X_train_res.index]

# %%
print("Distribution après sous-échantillonnage :")
print(y_train_res.value_counts())
print(f"\nTaille avant : {X_train_encoded.shape[0]} lignes")
print(f"Taille après : {X_train_res.shape[0]} lignes")
# Out:
# Distribution après sous-échantillonnage :
# default
# 1    3223
# 0    3223
# Name: count, dtype: int64
#
# Taille avant : 37488 lignes
# Taille après : 6446 lignes

# %% [markdown]
# *Ce code sert à corriger le déséquilibre des classes dans le jeu de données d’entraînement en utilisant une méthode de sous-échantillonnage aléatoire (Random Under-Sampling).*

# %%
# Régression Logistique + sous-échantillonnage 
model_lr_rus = LogisticRegression(max_iter=1000, random_state=42)
model_lr_rus.fit(X_train_res, y_train_res)

y_pred_lr_rus = model_lr_rus.predict(X_test_encoded)

print("Régression Logistique + RandomUnderSampler :")
print(classification_report(y_test, y_pred_lr_rus))
# Out:
# Régression Logistique + RandomUnderSampler :
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.95      0.66      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.93      0.81     12497
# weighted avg       0.95      0.92      0.93     12497

# %% [markdown]
# ####  Résultats — Régression Logistique + Sous-échantillonnage
# #### Classe 1 (défaut) — rappel très amélioré :
# ####    → Rappel 0.95 vs 0.73 (Tentative 2) → détecte 95% des défauts
# ####  Contrepartie :
# ####    → Précision classe 1 chute à 0.51
# ####  → Un défaut prédit sur deux est faux positif
# ####   → Accuracy globale baisse à 0.92 vs 0.96
# #### → Le sous-échantillonnage améliore fortement le rappel
# ####   mais dégrade la précision
# #### → En credit scoring : rappel prioritaire mais précision 0.51 trop faible

# %%
# ── XGBoost + sous-échantillonnage ────────────────────────
# Meilleurs hyperparamètres trouvés en Tentative 2
model_xgb_rus = XGBClassifier(
    **random_search.best_params_,
    random_state=42,
    eval_metric='logloss'
)
model_xgb_rus.fit(X_train_res, y_train_res)

y_pred_xgb_rus = model_xgb_rus.predict(X_test_encoded)

print("XGBoost + RandomUnderSampler :")
print(classification_report(y_test, y_pred_xgb_rus))
# Out:
# XGBoost + RandomUnderSampler :
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96     11423
#            1       0.57      0.97      0.72      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.95      0.84     12497
# weighted avg       0.96      0.93      0.94     12497

# %% [markdown]
# # Tentative 3

# %% [markdown]
# ### Régression logistique
#
# - Le déséquilibre des classes est traité à l’aide de la méthode **SMOTE Tomek**
# - Les hyperparamètres du modèle sont optimisés à l’aide de **Optuna**

# %%
# Traitement du déséquilibre — SMOTE manuel
# Régression Logistique + Optuna

from sklearn.neighbors import NearestNeighbors

def smote_manual(X, y, random_state=42):
    np.random.seed(random_state)
    
    X_minority = X[y == 1].values
    n_samples  = (y == 0).sum() - (y == 1).sum()
    
    # Trouver les k plus proches voisins de chaque exemple minoritaire
    nn = NearestNeighbors(n_neighbors=5)
    nn.fit(X_minority)
    indices = nn.kneighbors(X_minority, return_distance=False)
    
    # Générer des exemples synthétiques
    synthetic = []
    for i in range(n_samples):
        idx    = np.random.randint(0, len(X_minority))
        nn_idx = indices[idx][np.random.randint(1, 5)]
        lam    = np.random.random()
        synthetic.append(X_minority[idx] + lam * (X_minority[nn_idx] - X_minority[idx]))
    
    X_synthetic = pd.DataFrame(synthetic, columns=X.columns)
    y_synthetic = pd.Series([1] * n_samples)
    
    X_res = pd.concat([X, X_synthetic]).reset_index(drop=True)
    y_res = pd.concat([y.reset_index(drop=True), y_synthetic]).reset_index(drop=True)
    
    return X_res, y_res

X_train_smt, y_train_smt = smote_manual(X_train_encoded, y_train)

print("Distribution après SMOTE :")
print(y_train_smt.value_counts())
print(f"\nTaille avant : {X_train_encoded.shape[0]} lignes")
print(f"Taille après : {X_train_smt.shape[0]} lignes")
# Out:
# Distribution après SMOTE :
# 0    34265
# 1    34265
# Name: count, dtype: int64
#
# Taille avant : 37488 lignes
# Taille après : 68530 lignes

# %%
# Régression Logistique + SMOTE 
model_lr_smt = LogisticRegression(max_iter=1000, random_state=42)
model_lr_smt.fit(X_train_smt, y_train_smt)

y_pred_lr_smt = model_lr_smt.predict(X_test_encoded)

print("Régression Logistique + SMOTE :")
print(classification_report(y_test, y_pred_lr_smt))
# Out:
# Régression Logistique + SMOTE :
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.55      0.94      0.69      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
# ── Optimisation — Optuna ─────────────────────────────────
import optuna
from sklearn.metrics import f1_score
optuna.logging.set_verbosity(optuna.logging.WARNING)

def objective(trial):
    C      = trial.suggest_float('C', 1e-4, 1e4, log=True)
    solver = trial.suggest_categorical('solver', ['lbfgs', 'saga', 'liblinear'])
    
    model = LogisticRegression(C=C, solver=solver, max_iter=10000, random_state=42)
    model.fit(X_train_smt, y_train_smt)
    
    return f1_score(y_test, model.predict(X_test_encoded))

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

print(f"Meilleurs paramètres : {study.best_params}")
print(f"Meilleur score F1    : {study.best_value:.4f}")
# Out:
# Meilleurs paramètres : {'C': 1227.6798014510482, 'solver': 'liblinear'}
# Meilleur score F1    : 0.6976

# %%
# ── Meilleur modèle ───────────────────────────────────────
best_model_lr_smt = LogisticRegression(
    **study.best_params,
    max_iter=10000,
    random_state=42
)
best_model_lr_smt.fit(X_train_smt, y_train_smt)

y_pred_lr_smt_optuna = best_model_lr_smt.predict(X_test_encoded)

print("Régression Logistique + SMOTE + Optuna :")
print(classification_report(y_test, y_pred_lr_smt_optuna))
# Out:
# Régression Logistique + SMOTE + Optuna :
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.55      0.95      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %% [markdown]
# ####  Résultats — Régression Logistique + SMOTE + Optuna
# ####  Classe 1 (défaut) — rappel excellent :
# ####   Rappel 0.95 → détecte 95% des défauts
# ####   Meilleur résultat obtenu jusqu'ici sur la classe 1
#
# ####  Contrepartie :
# ####    → Précision classe 1 = 0.55 → beaucoup de faux positifs
# ####    → F1 classe 1 = 0.70 → en dessous des tentatives sans rééchantillonnage
#
# #### → SMOTE + Optuna améliore légèrement la précision vs RUS (0.55 vs 0.51)
# ####   tout en maintenant un rappel de 0.95
# #### → Meilleur compromis rappel/précision parmi les tentatives avec rééchantillonnage
# #### → Mais F1 classe 1 (0.70) reste inférieur aux tentatives sans rééchantillonnage (0.78)

# %% [markdown]
# ### Tentative 3
# ##### XGBoost
# ###### Gérer le déséquilibre des classes à l'aide de SMOTE Tomek
# ###### Réglage des paramètres avec optuna

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.metrics import f1_score
optuna.logging.set_verbosity(optuna.logging.WARNING)

def objective_xgb(trial):
    params = {
        'n_estimators'    : trial.suggest_int('n_estimators', 100, 300),
        'max_depth'       : trial.suggest_int('max_depth', 3, 10),
        'learning_rate'   : trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample'       : trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha'       : trial.suggest_float('reg_alpha', 0.01, 10.0, log=True),
        'reg_lambda'      : trial.suggest_float('reg_lambda', 0.01, 10.0, log=True),
    }
    
    model = XGBClassifier(**params, random_state=42, eval_metric='logloss')
    model.fit(X_train_smt, y_train_smt)
    
    return f1_score(y_test, model.predict(X_test_encoded))

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective_xgb, n_trials=50)

print(f"Meilleurs paramètres : {study_xgb.best_params}")
print(f"Meilleur score F1    : {study_xgb.best_value:.4f}")
# Out:
# Meilleurs paramètres : {'n_estimators': 289, 'max_depth': 4, 'learning_rate': 0.20882673007433253, 'subsample': 0.874225791532417, 'colsample_bytree': 0.6820052023848188, 'reg_alpha': 0.8368726316668819, 'reg_lambda': 0.21757962986668597}
# Meilleur score F1    : 0.7998

# %%
# ── Meilleur modèle XGBoost + SMOTE + Optuna ──────────────
best_model_xgb_smt = XGBClassifier(
    **study_xgb.best_params,
    random_state=42,
    eval_metric='logloss'
)
best_model_xgb_smt.fit(X_train_smt, y_train_smt)

y_pred_xgb_smt = best_model_xgb_smt.predict(X_test_encoded)

print("XGBoost + SMOTE + Optuna :")
print(classification_report(y_test, y_pred_xgb_smt))
# Out:
# XGBoost + SMOTE + Optuna :
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     11423
#            1       0.76      0.85      0.80      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.87      0.91      0.89     12497
# weighted avg       0.97      0.96      0.96     12497

# %% [markdown]
# Pour la suite on retiendra le modèle de la régression logistique du fait de sa meilleure interprétabilité

# %% [markdown]
# ### Evaluation du modèle : ROC/AUC

# %%
# Évaluation du modèle final retenu (standard)
# Régression Logistique + RandomizedSearchCV
# Pour un scoring bancaire, on retient le modèle sans rééchantillonnage
# → probabilités bien calibrées et représentatives de la vraie distribution

y_pred = best_model_logistic.predict(X_test_encoded)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.83      0.73      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
# ── Calcul de la courbe ROC ───────────────────────────────
# predict_proba → probabilités d'appartenance à la classe 1 (défaut)
# fpr = taux de faux positifs | tpr = taux de vrais positifs

from sklearn.metrics import roc_curve, auc

probabilities = best_model_logistic.predict_proba(X_test_encoded)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, probabilities)

print("FPR :", fpr[:5])
print("TPR :", tpr[:5])
print("Seuils :", thresholds[:5])
# Out:
# FPR : [0.00000000e+00 0.00000000e+00 0.00000000e+00 8.75426771e-05
#  8.75426771e-05]
# TPR : [0.         0.0009311  0.26908752 0.26908752 0.27374302]
# Seuils : [       inf 0.99999994 0.95565595 0.95563062 0.95354322]

# %%
# ── Calcul de l'AUC ───────────────────────────────────────
# AUC = aire sous la courbe ROC
# 0.5 → modèle aléatoire | 1.0 → modèle parfait

area = auc(fpr, tpr)
print(f"AUC : {area:.4f}")
# Out:
# AUC : 0.9835

# %%
# ── Tracé de la courbe ROC ────────────────────────────────
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2,
         label=f'Courbe ROC (AUC = {area:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2,
         linestyle='--', label='Modèle aléatoire (AUC = 0.50)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taux de faux positifs (FPR)')
plt.ylabel('Taux de vrais positifs (TPR)')

# modèle final sans rééchantillonnage
plt.title('Courbe ROC — Régression Logistique + RandomizedSearchCV')

plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# 📊 Interprétation :
# AUC > 0.90 → excellent pouvoir discriminant
# AUC > 0.80 → bon modèle
# AUC = 0.50 → modèle sans pouvoir prédictif (aléatoire)

# %% [markdown]
# ### AUC : 0.9833
# ### AUC > 0.90 → excellent pouvoir discriminant

# %% [markdown]
# # Evaluation du modèle : Rankordering, KS statistic, Gini coeff

# %%
# ── Rank Ordering (table des déciles) ────────────────────
# Trier les observations par probabilité de défaut décroissante
# Vérifier que les défauts se concentrent dans les premiers déciles

decile_df = pd.DataFrame({
    'y_test'      : y_test.values,
    'probability' : probabilities  
})

# Découpage en déciles selon la probabilité prédite
decile_df['decile'] = pd.qcut(
    decile_df['probability'], q=10, labels=False, duplicates='drop'
)
decile_df['decile'] = 9 - decile_df['decile']  # Décile 0 = probabilité la plus haute

# Agrégation par décile
rank_order = decile_df.groupby('decile').agg(
    total  = ('y_test', 'count'),
    events = ('y_test', 'sum'),
).reset_index()

rank_order['non_events']        = rank_order['total'] - rank_order['events']
rank_order['event_rate']        = (rank_order['events'] / rank_order['total']).round(4)
rank_order['cum_events']        = rank_order['events'].cumsum()
rank_order['cum_non_events']    = rank_order['non_events'].cumsum()
rank_order['cum_event_pct']     = (rank_order['cum_events'] / rank_order['events'].sum()).round(4)
rank_order['cum_non_event_pct'] = (rank_order['cum_non_events'] / rank_order['non_events'].sum()).round(4)

# %%
# Statistique KS par décile
rank_order['KS'] = (rank_order['cum_event_pct'] - rank_order['cum_non_event_pct']).abs().round(4)

print("Table des déciles — Rank Ordering :")
print(rank_order.to_string(index=False))
# Out:
# Table des déciles — Rank Ordering :
#  decile  total  events  non_events  event_rate  cum_events  cum_non_events  cum_event_pct  cum_non_event_pct       KS
#       0   1250     901         349    0.720800         901             349       0.838900           0.030600 0.808300
#       1   1250     153        1097    0.122400        1054            1446       0.981400           0.126600 0.854800
#       2   1249      15        1234    0.012000        1069            2680       0.995300           0.234600 0.760700
#       3   1250       5        1245    0.004000        1074            3925       1.000000           0.343600 0.656400
#       4   1249       0        1249    0.000000        1074            5174       1.000000           0.452900 0.547100
#       5   1250       0        1250    0.000000        1074            6424       1.000000           0.562400 0.437600
#       6   1250       0        1250    0.000000        1074            7674       1.000000           0.671800 0.328200
#       7   1249       0        1249    0.000000        1074            8923       1.000000           0.781100 0.218900
#       8   1250       0        1250    0.000000        1074           10173       1.000000           0.890600 0.109400
#       9   1250       0        1250    0.000000        1074           11423       1.000000           1.000000 0.000000

# %% [markdown]
# #### Analyse de la table des déciles — Rank Ordering
#
# #### 🔴 Déciles à fort risque (0 et 1) :
# ####    → Décile 0 : taux d'événements = 72.1% → le modèle concentre
# ####      83.9% de tous les défauts dans ce seul décile
# ####    → Décile 1 : taux d'événements = 12.2% → taux cumulé atteint 98.1%
# ####      dès le 2ème décile → quasi-totalité des défauts détectés
# #### 🟡 Déciles intermédiaires (2 et 3) :
# ####    → Taux d'événements quasi nuls (1.2% et 0.4%)
# ####    → Taux cumulé atteint 100% dès le décile 3
# #### 🟢 Déciles inférieurs (4 à 9) :
# ####    → Aucun défaut observé (event_rate = 0.000)
# ####    → 100% de non-défauts → le modèle n'envoie aucun défaut
# ####      dans la moitié inférieure du classement
# ####   KS maximum = 85.5% au décile 1
# ####    → Règle pratique : KS > 40% dans les 3 premiers déciles = bon modèle
# ####    → Ici KS = 85.5% au décile 1 → modèle excellent ✅

# %%
# ── KS Statistic ─────────────────────────────────────────
# KS = différence maximale entre la distribution cumulée
# des événements et des non-événements
# KS > 40% → bon modèle | KS > 60% → excellent modèle

ks_stat   = rank_order['KS'].max()
ks_decile = rank_order.loc[rank_order['KS'].idxmax(), 'decile']

print(f"KS Statistic  : {ks_stat:.4f} ({ks_stat*100:.2f}%)")
print(f"Décile optimal : {ks_decile}")

# 📊 Interprétation :
# < 0.20       → modèle faible
# 0.20 – 0.40  → modèle acceptable
# 0.40 – 0.60  → bon modèle
# > 0.60       → excellent modèle
# Out:
# KS Statistic  : 0.8548 (85.48%)
# Décile optimal : 1

# %% [markdown]
# Excellent modèle

# %%
#  Visualisation KS
plt.figure(figsize=(10, 5))

plt.plot(rank_order['decile'], rank_order['cum_event_pct'],
         marker='o', label='Événements cumulés (défauts)', color='red')

plt.plot(rank_order['decile'], rank_order['cum_non_event_pct'],
         marker='o', label='Non-événements cumulés', color='blue')

plt.bar(rank_order['decile'], rank_order['KS'],
        alpha=0.3, color='green', label='KS par décile')

plt.axvline(x=ks_decile, color='green', linestyle='--',
            label=f'KS max = {ks_stat:.2%} au décile {ks_decile}')

plt.xlabel('Décile')
plt.ylabel('Taux cumulé')
plt.title('KS Statistic — Rank Ordering')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Le modèle présente un excellent pouvoir discriminant avec un KS de 85.48%
# atteint dès le décile 1, ce qui signifie que la quasi-totalité des défauts
# est concentrée dans les 2 premiers déciles. La courbe des défauts (rouge)
# atteint 100% très rapidement tandis que la courbe des non-défauts (bleue)
# progresse linéairement, confirmant une très bonne séparation entre les deux
# classes.
# Le modèle est donc très efficace pour identifier les clients à risque.

# %%
# Gini Coefficient 
# Gini = 2 * AUC - 1
# Mesure la capacité du modèle à distinguer les classes
# Gini = 0 → modèle aléatoire | Gini = 1 → modèle parfait

gini_coefficient = 2 * area - 1

print(f"AUC              : {area:.4f}")
print(f"Gini Coefficient : {gini_coefficient:.4f}")

# 📊 Interprétation :
# < 0.20 → modèle faible
# 0.20–0.40 → modèle acceptable
# 0.40–0.60 → bon modèle
# > 0.60 → excellent modèle
# Out:
# AUC              : 0.9835
# Gini Coefficient : 0.9671

# %% [markdown]
# Excellent modèle

# %% [markdown]
# ## Finalisation du modèle et visualisation de l’importance des caractéristiques

# %%
final_model = best_model_logistic

# %% [markdown]
# ### Importance des variables

# %%
# Coefficient positif → augmente le risque de défaut
# Coefficient négatif → diminue le risque de défaut

feature_importance = final_model.coef_[0]

coef_df = pd.DataFrame(
    feature_importance,
    index=X_train_encoded.columns,
    columns=['Coefficients']
).sort_values(by='Coefficients', ascending=True)

plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.axvline(x=0, color='black', linestyle='--', linewidth=0.8)
plt.xlabel('Valeur du coefficient')

# modèle final retenu
plt.title("Importance des variables — Régression Logistique + RandomizedSearchCV")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔴 Variables augmentant le risque de défaut (coefficients positifs) :
#    → credit_utilization_ratio : variable la plus impactante
#
#    → loan_to_income           : ratio endettement/revenu élevé = risque élevé
#
#    → delinquency_ratio        : historique de retards = fort signal de défaut
# ### 🟢 Variables réduisant le risque de défaut (coefficients négatifs) :
#    → loan_purpose_Home        : prêt immobilier = profil plus fiable
#
#    → residence_type_Owned     : propriétaire = stabilité financière

# %% [markdown]
# ## Sauvegarde du modèle

# %%
X_test_encoded.head(2)
# Out:
#            age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346154            0.754717                 0.333333
# 15514 0.480769            0.226415                 1.000000
#
#        credit_utilization_ratio  residence_type_Owned  residence_type_Rented  \
# 19205                  0.989899                     1                      0
# 15514                  0.323232                     1                      0
#
#        loan_purpose_Home  loan_purpose_Personal  loan_type_Unsecured  \
# 19205                  1                      0                    0
# 15514                  0                      0                    0
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 19205        0.550351           0.000000                 0.000000
# 15514        0.220141           0.000000                 0.000000

# %%
X_test_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Home', 'loan_purpose_Personal',
#        'loan_type_Unsecured', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
cols_to_scale
# Out:
# ['age',
#  'number_of_dependants',
#  'years_at_current_address',
#  'loan_tenure_months',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'enquiry_count',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %%
from joblib import dump

model_data = {
    'model'        : final_model,
    'features'     : X_train_encoded.columns,
    'scaler'       : scaler,
    'cols_to_scale': cols_to_scale
}

dump(model_data, 'model_data.joblib')
print("Modèle sauvegardé dans 'model_data.joblib'")
# Out:
# Modèle sauvegardé dans 'model_data.joblib'

# %%
print("Coefficients  :", final_model.coef_)
print("Intercept     :", final_model.intercept_)
# Out:
# Coefficients  : [[ 0.32337211  0.90590142  0.79850893 14.72726309 -1.66494886  1.60391384
#   -3.73783471  0.75221479  0.75221479 15.82418595 10.95975342  2.07235893]]
# Intercept     : [-20.69757569]

# %%
# ── Aperçu des coefficients du modèle 
coef_df = pd.DataFrame(
    final_model.coef_[0],
    index=X_train_encoded.columns,
    columns=['Coefficients']
).sort_values('Coefficients', ascending=False)

print("Intercept :", round(final_model.intercept_[0], 4))
print()
print(coef_df)
# Out:
# Intercept : -20.6976
#
#                           Coefficients
# loan_to_income               15.824186
# credit_utilization_ratio     14.727263
# delinquency_ratio            10.959753
# avg_dpd_per_delinquency       2.072359
# residence_type_Rented         1.603914
# loan_tenure_months            0.905901
# number_of_open_accounts       0.798509
# loan_purpose_Personal         0.752215
# loan_type_Unsecured           0.752215
# age                           0.323372
# residence_type_Owned         -1.664949
# loan_purpose_Home            -3.737835
